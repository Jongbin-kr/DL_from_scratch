# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
sys.path.append('./fashion-mnist/utils/')

# %%
import mnist_reader
x_train, t_train = mnist_reader.load_mnist('./fashion-mnist/data/fashion', kind='train')
x_test, t_test = mnist_reader.load_mnist('./fashion-mnist/data/fashion', kind='t10k')

## data normalization
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (60000, 784)
# 1.0
# (60000,)

# %%
network_dict = {
                'step': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='step', weight_init_std=0.01),
                'sigmoid': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='sigmoid', weight_init_std=0.01),
                'tanh': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='tanh', weight_init_std=0.01),
                'relu': MultiLayerNetExtend(input_size=784, hidden_size_list=[50], output_size=10, activation='relu', weight_init_std=0.01),
                'leaky': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std=0.01),
                }

# %%
network_dict['relu'].params.keys()
# Out:
# dict_keys(['W1', 'b1', 'W2', 'b2'])

# %%
# 하이퍼 파라메터
iters_num = 10_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === step network training start ===
# --- step result report ---
# train acc, test acc | 0.15718333333333334, 0.1572
# --- step result report ---
# train acc, test acc | 0.7389666666666667, 0.7266
# --- step result report ---
# train acc, test acc | 0.7486333333333334, 0.7381
# --- step result report ---
# train acc, test acc | 0.7530833333333333, 0.7445
# --- step result report ---
# train acc, test acc | 0.7553166666666666, 0.747
# --- step result report ---
# train acc, test acc | 0.7590666666666667, 0.7483
# --- step result report ---
# train acc, test acc | 0.7592, 0.7495
# --- step result report ---
# train acc, test acc | 0.7619, 0.7521
# --- step result report ---
# train acc, test acc | 0.7623666666666666, 0.7528
# --- step result report ---
# train acc, test acc | 0.7623, 0.7521
# --- step result report ---
# train acc, test acc | 0.76235, 0.7522
# --- step result report ---
# train acc, test acc | 0.7590833333333333, 0.7462
# --- step result report ---
# train acc, test acc | 0.7621666666666667, 0.7539
# --- step result report ---
# train acc, test acc | 0.7648, 0.7526
# --- step result report ---
# train acc, test acc | 0.7642833333333333, 0.7541
# --- step result report ---
# train acc, test acc | 0.7653166666666666, 0.7537
# --- step result report ---
# train acc, test acc | 0.7637333333333334, 0.7498
# ==========
#
#
#
# === sigmoid network training start ===
# --- sigmoid result report ---
# train acc, test acc | 0.1, 0.1
# --- sigmoid result report ---
# train acc, test acc | 0.7198333333333333, 0.7139
# --- sigmoid result report ---
# train acc, test acc | 0.7737333333333334, 0.7655
# --- sigmoid result report ---
# train acc, test acc | 0.8071333333333334, 0.7979
# --- sigmoid result report ---
# train acc, test acc | 0.8218666666666666, 0.8103
# --- sigmoid result report ---
# train acc, test acc | 0.8291333333333334, 0.8135
# --- sigmoid result report ---
# train acc, test acc | 0.84035, 0.827
# --- sigmoid result report ---
# train acc, test acc | 0.84445, 0.8321
# --- sigmoid result report ---
# train acc, test acc | 0.8458166666666667, 0.8328
# --- sigmoid result report ---
# train acc, test acc | 0.84875, 0.8336
# --- sigmoid result report ---
# train acc, test acc | 0.8541166666666666, 0.8393
# --- sigmoid result report ---
# train acc, test acc | 0.8550833333333333, 0.8417
# --- sigmoid result report ---
# train acc, test acc | 0.8577666666666667, 0.8442
# --- sigmoid result report ---
# train acc, test acc | 0.8614833333333334, 0.8451
# --- sigmoid result report ---
# train acc, test acc | 0.8625833333333334, 0.8468
# --- sigmoid result report ---
# train acc, test acc | 0.8652666666666666, 0.8495
# --- sigmoid result report ---
# train acc, test acc | 0.8686833333333334, 0.8489
# ==========
#
#
#
# === tanh network training start ===
# --- tanh result report ---
# train acc, test acc | 0.1247, 0.1233
# --- tanh result report ---
# train acc, test acc | 0.82515, 0.8155
# --- tanh result report ---
# train acc, test acc | 0.8461833333333333, 0.8325
# --- tanh result report ---
# train acc, test acc | 0.85175, 0.8355
# --- tanh result report ---
# train acc, test acc | 0.8498166666666667, 0.8329
# --- tanh result report ---
# train acc, test acc | 0.86815, 0.8518
# --- tanh result report ---
# train acc, test acc | 0.8626666666666667, 0.8475
# --- tanh result report ---
# train acc, test acc | 0.8682166666666666, 0.8504
# --- tanh result report ---
# train acc, test acc | 0.8787833333333334, 0.8591
# --- tanh result report ---
# train acc, test acc | 0.8735666666666667, 0.8531
# --- tanh result report ---
# train acc, test acc | 0.8766333333333334, 0.8549
# --- tanh result report ---
# train acc, test acc | 0.8855333333333333, 0.8633
# --- tanh result report ---
# train acc, test acc | 0.8882833333333333, 0.8681
# --- tanh result report ---
# train acc, test acc | 0.8896, 0.867
# --- tanh result report ---
# train acc, test acc | 0.89525, 0.8712
# --- tanh result report ---
# train acc, test acc | 0.89385, 0.8691
# --- tanh result report ---
# train acc, test acc | 0.89445, 0.8712
# ==========
#
#
#
# === relu network training start ===
# --- relu result report ---
# train acc, test acc | 0.101, 0.1011
# --- relu result report ---
# train acc, test acc | 0.80315, 0.7907
# --- relu result report ---
# train acc, test acc | 0.8426333333333333, 0.8284
# --- relu result report ---
# train acc, test acc | 0.85175, 0.839
# --- relu result report ---
# train acc, test acc | 0.8621833333333333, 0.8453
# --- relu result report ---
# train acc, test acc | 0.8619666666666667, 0.8468
# --- relu result report ---
# train acc, test acc | 0.8583, 0.8411
# --- relu result report ---
# train acc, test acc | 0.8593833333333334, 0.8418
# --- relu result report ---
# train acc, test acc | 0.8580666666666666, 0.8368
# --- relu result report ---
# train acc, test acc | 0.8790666666666667, 0.8612
# --- relu result report ---
# train acc, test acc | 0.8822666666666666, 0.8609
# --- relu result report ---
# train acc, test acc | 0.8888166666666667, 0.8675
# --- relu result report ---
# train acc, test acc | 0.8804166666666666, 0.8573
# --- relu result report ---
# train acc, test acc | 0.8817333333333334, 0.8575
# --- relu result report ---
# train acc, test acc | 0.89, 0.8655
# --- relu result report ---
# train acc, test acc | 0.8912333333333333, 0.8704
# --- relu result report ---
# train acc, test acc | 0.8947333333333334, 0.8723
# ==========
#
#
#
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.16508333333333333, 0.1601
# --- leaky result report ---
# train acc, test acc | 0.81925, 0.8082
# --- leaky result report ---
# train acc, test acc | 0.8482833333333333, 0.8345
# --- leaky result report ---
# train acc, test acc | 0.8578666666666667, 0.8435
# --- leaky result report ---
# train acc, test acc | 0.8619, 0.8478
# --- leaky result report ---
# train acc, test acc | 0.8710666666666667, 0.8564
# --- leaky result report ---
# train acc, test acc | 0.8730333333333333, 0.8571
# --- leaky result report ---
# train acc, test acc | 0.88145, 0.8609
# --- leaky result report ---
# train acc, test acc | 0.8827333333333334, 0.8664
# --- leaky result report ---
# train acc, test acc | 0.8812166666666666, 0.8616
# --- leaky result report ---
# train acc, test acc | 0.8850166666666667, 0.8649
# --- leaky result report ---
# train acc, test acc | 0.89205, 0.8708
# --- leaky result report ---
# train acc, test acc | 0.8935833333333333, 0.872
# --- leaky result report ---
# train acc, test acc | 0.89155, 0.8704
# --- leaky result report ---
# train acc, test acc | 0.8877833333333334, 0.8641
# --- leaky result report ---
# train acc, test acc | 0.89895, 0.8761
# --- leaky result report ---
# train acc, test acc | 0.89635, 0.8718
# ==========

# %%
for k, v in output_dict.items():
    print(k)
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
    
plt.legend()
plt.grid()
# Out:
# step train acc
# step test acc
# sigmoid train acc
# sigmoid test acc
# tanh train acc
# tanh test acc
# relu train acc
# relu test acc
# leaky train acc
# leaky test acc
