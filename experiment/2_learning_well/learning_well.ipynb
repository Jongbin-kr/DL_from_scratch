# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
test_dict = {}
train_dict = {}
root_path = '../how_deep_is_your_thought/cifar-10-batches-py/'


def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

accepted_keys = [b'labels', b'data'] ## select keys from [b'batch_label', b'labels', b'data', b'filenames']
for dir in os.listdir(root_path):
    if dir == 'batches.meta':
        pass
    elif dir == 'test_batch':
        test_batch = unpickle(os.path.join(root_path, dir))
        test_dict.update((k,np.array(v)) for k,v in test_batch.items() if k in accepted_keys)
    else:
        train_batch = unpickle(os.path.join(root_path, dir))
        if not train_dict:
            train_dict.update((k,np.array(v)) for k,v in train_batch.items() if k in accepted_keys)
        else:
            for key in accepted_keys:
                train_dict[key] = np.concatenate((train_dict[key], train_batch[key]), axis=0)


## CIFAR data's shape are (N, H*W*C). 
## If you want to convert them into numpy-standard (N, H, W, C) shape, run following codes.
def numpy2rgb(arr: np.ndarray) -> np.ndarray:
    batch_size = len(arr)
    arr = arr.reshape(batch_size, 3, 32, 32).transpose(0,2,3,1)
    
    return arr


train_dict[b'data'] = numpy2rgb(train_dict[b'data'])
test_dict[b'data'] = numpy2rgb(test_dict[b'data'])

# %%
## load and normalize datasets
x_train, t_train = train_dict[b'data'] / 255.0, train_dict[b'labels']
x_test, t_test = test_dict[b'data'] / 255.0, test_dict[b'labels']

# %%
print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 1.0
# (50000,)

# %%
network_dict = {
                # 'step': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='step', weight_init_std=0.01),
                'sigmoid': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='sigmoid', weight_init_std='sigmoid', weight_decay_lambda=0.1, use_batchnorm=True),
                'tanh': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='tanh', weight_init_std='sigmoid', weight_decay_lambda=0.1, use_batchnorm=True),
                'relu': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[50], output_size=10, activation='relu', weight_init_std='relu', weight_decay_lambda=0.1, use_batchnorm=True),
                'leaky': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='relu', weight_decay_lambda=0.1, use_batchnorm=True),
                }

# %%
network_dict['leaky'].params.keys()
# Out:
# dict_keys(['W1', 'b1', 'W2', 'b2', 'gamma1', 'beta1'])

# %%
# 하이퍼 파라메터
iters_num = 50_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === sigmoid network training start ===
# --- sigmoid result report ---
# train acc, test acc | 0.11652, 0.1186
# --- sigmoid result report ---
# train acc, test acc | 0.29016, 0.2873
# --- sigmoid result report ---
# train acc, test acc | 0.19702, 0.2007
# --- sigmoid result report ---
# train acc, test acc | 0.19274, 0.1914
# --- sigmoid result report ---
# train acc, test acc | 0.2762, 0.2758
# --- sigmoid result report ---
# train acc, test acc | 0.2814, 0.2763
# --- sigmoid result report ---
# train acc, test acc | 0.23916, 0.2422
# --- sigmoid result report ---
# train acc, test acc | 0.194, 0.1911
# --- sigmoid result report ---
# train acc, test acc | 0.1865, 0.1923
# --- sigmoid result report ---
# train acc, test acc | 0.27654, 0.279
# --- sigmoid result report ---
# train acc, test acc | 0.17346, 0.1721
# --- sigmoid result report ---
# train acc, test acc | 0.17554, 0.1773
# --- sigmoid result report ---
# train acc, test acc | 0.20064, 0.2005
# --- sigmoid result report ---
# train acc, test acc | 0.28298, 0.2734
# --- sigmoid result report ---
# train acc, test acc | 0.28918, 0.2834
# --- sigmoid result report ---
# train acc, test acc | 0.21374, 0.213
# --- sigmoid result report ---
# train acc, test acc | 0.27166, 0.2703
# --- sigmoid result report ---
# train acc, test acc | 0.2733, 0.2682
# --- sigmoid result report ---
# train acc, test acc | 0.16216, 0.1604
# --- sigmoid result report ---
# train acc, test acc | 0.2777, 0.283
# --- sigmoid result report ---
# train acc, test acc | 0.2762, 0.2744
# --- sigmoid result report ---
# train acc, test acc | 0.28562, 0.2805
# --- sigmoid result report ---
# train acc, test acc | 0.26214, 0.2592
# --- sigmoid result report ---
# train acc, test acc | 0.24822, 0.2452
# --- sigmoid result report ---
# train acc, test acc | 0.2371, 0.236
# --- sigmoid result report ---
# train acc, test acc | 0.24108, 0.2437
# --- sigmoid result report ---
# train acc, test acc | 0.23592, 0.2315
# --- sigmoid result report ---
# train acc, test acc | 0.28546, 0.2874
# --- sigmoid result report ---
# train acc, test acc | 0.25622, 0.2533
# --- sigmoid result report ---
# train acc, test acc | 0.20086, 0.2
# --- sigmoid result report ---
# train acc, test acc | 0.17786, 0.1779
# --- sigmoid result report ---
# train acc, test acc | 0.20358, 0.2027
# --- sigmoid result report ---
# train acc, test acc | 0.29598, 0.2942
# --- sigmoid result report ---
# train acc, test acc | 0.24214, 0.2386
# --- sigmoid result report ---
# train acc, test acc | 0.28896, 0.2857
# --- sigmoid result report ---
# train acc, test acc | 0.22912, 0.2346
# --- sigmoid result report ---
# train acc, test acc | 0.17702, 0.1786
# --- sigmoid result report ---
# train acc, test acc | 0.2677, 0.2686
# --- sigmoid result report ---
# train acc, test acc | 0.26904, 0.2727
# --- sigmoid result report ---
# train acc, test acc | 0.21072, 0.2117
# --- sigmoid result report ---
# train acc, test acc | 0.30904, 0.3099
# --- sigmoid result report ---
# train acc, test acc | 0.28066, 0.2749
# --- sigmoid result report ---
# train acc, test acc | 0.28612, 0.2901
# --- sigmoid result report ---
# train acc, test acc | 0.22486, 0.2333
# --- sigmoid result report ---
# train acc, test acc | 0.22078, 0.2194
# --- sigmoid result report ---
# train acc, test acc | 0.27272, 0.2704
# --- sigmoid result report ---
# train acc, test acc | 0.27998, 0.281
# --- sigmoid result report ---
# train acc, test acc | 0.2716, 0.2742
# --- sigmoid result report ---
# train acc, test acc | 0.23392, 0.2404
# --- sigmoid result report ---
# train acc, test acc | 0.25104, 0.2558
# --- sigmoid result report ---
# train acc, test acc | 0.27856, 0.2789
# --- sigmoid result report ---
# train acc, test acc | 0.24056, 0.2327
# --- sigmoid result report ---
# train acc, test acc | 0.24912, 0.2498
# --- sigmoid result report ---
# train acc, test acc | 0.2457, 0.2486
# --- sigmoid result report ---
# train acc, test acc | 0.17496, 0.1725
# --- sigmoid result report ---
# train acc, test acc | 0.21868, 0.2159
# --- sigmoid result report ---
# train acc, test acc | 0.26736, 0.2671
# --- sigmoid result report ---
# train acc, test acc | 0.19132, 0.189
# --- sigmoid result report ---
# train acc, test acc | 0.2773, 0.2712
# --- sigmoid result report ---
# train acc, test acc | 0.25146, 0.2485
# --- sigmoid result report ---
# train acc, test acc | 0.31278, 0.3135
# --- sigmoid result report ---
# train acc, test acc | 0.18332, 0.1801
# --- sigmoid result report ---
# train acc, test acc | 0.21268, 0.2098
# --- sigmoid result report ---
# train acc, test acc | 0.22604, 0.2287
# --- sigmoid result report ---
# train acc, test acc | 0.20408, 0.2066
# --- sigmoid result report ---
# train acc, test acc | 0.20306, 0.2021
# --- sigmoid result report ---
# train acc, test acc | 0.18246, 0.1834
# --- sigmoid result report ---
# train acc, test acc | 0.20664, 0.2012
# --- sigmoid result report ---
# train acc, test acc | 0.2058, 0.2029
# --- sigmoid result report ---
# train acc, test acc | 0.26898, 0.2653
# --- sigmoid result report ---
# train acc, test acc | 0.21304, 0.2114
# --- sigmoid result report ---
# train acc, test acc | 0.27448, 0.2782
# --- sigmoid result report ---
# train acc, test acc | 0.26638, 0.2618
# --- sigmoid result report ---
# train acc, test acc | 0.21018, 0.2067
# --- sigmoid result report ---
# train acc, test acc | 0.13326, 0.1348
# --- sigmoid result report ---
# train acc, test acc | 0.19096, 0.1898
# --- sigmoid result report ---
# train acc, test acc | 0.2416, 0.2431
# --- sigmoid result report ---
# train acc, test acc | 0.25448, 0.2522
# --- sigmoid result report ---
# train acc, test acc | 0.31214, 0.3136
# --- sigmoid result report ---
# train acc, test acc | 0.2531, 0.2536
# --- sigmoid result report ---
# train acc, test acc | 0.25512, 0.258
# --- sigmoid result report ---
# train acc, test acc | 0.19392, 0.1901
# --- sigmoid result report ---
# train acc, test acc | 0.15308, 0.1556
# --- sigmoid result report ---
# train acc, test acc | 0.28534, 0.2915
# --- sigmoid result report ---
# train acc, test acc | 0.24318, 0.2485
# --- sigmoid result report ---
# train acc, test acc | 0.1881, 0.1835
# --- sigmoid result report ---
# train acc, test acc | 0.22962, 0.2326
# --- sigmoid result report ---
# train acc, test acc | 0.18074, 0.1808
# --- sigmoid result report ---
# train acc, test acc | 0.2703, 0.2694
# --- sigmoid result report ---
# train acc, test acc | 0.2828, 0.275
# --- sigmoid result report ---
# train acc, test acc | 0.24274, 0.2424
# --- sigmoid result report ---
# train acc, test acc | 0.30836, 0.3068
# --- sigmoid result report ---
# train acc, test acc | 0.20288, 0.2058
# --- sigmoid result report ---
# train acc, test acc | 0.31246, 0.3048
# --- sigmoid result report ---
# train acc, test acc | 0.26558, 0.2631
# --- sigmoid result report ---
# train acc, test acc | 0.1739, 0.1707
# --- sigmoid result report ---
# train acc, test acc | 0.29098, 0.2887
# --- sigmoid result report ---
# train acc, test acc | 0.30824, 0.3051
# --- sigmoid result report ---
# train acc, test acc | 0.2496, 0.2436
# --- sigmoid result report ---
# train acc, test acc | 0.30158, 0.299
# ==========
#
#
#
# === tanh network training start ===
# --- tanh result report ---
# train acc, test acc | 0.09992, 0.1001
# --- tanh result report ---
# train acc, test acc | 0.24394, 0.2456
# --- tanh result report ---
# train acc, test acc | 0.28014, 0.2835
# --- tanh result report ---
# train acc, test acc | 0.23192, 0.2357
# --- tanh result report ---
# train acc, test acc | 0.30376, 0.3054
# --- tanh result report ---
# train acc, test acc | 0.23718, 0.235
# --- tanh result report ---
# train acc, test acc | 0.21686, 0.2177
# --- tanh result report ---
# train acc, test acc | 0.24208, 0.2414
# --- tanh result report ---
# train acc, test acc | 0.21918, 0.221
# --- tanh result report ---
# train acc, test acc | 0.19916, 0.2008
# --- tanh result report ---
# train acc, test acc | 0.27126, 0.2664
# --- tanh result report ---
# train acc, test acc | 0.26248, 0.2539
# --- tanh result report ---
# train acc, test acc | 0.2411, 0.2404
# --- tanh result report ---
# train acc, test acc | 0.24924, 0.2445
# --- tanh result report ---
# train acc, test acc | 0.19516, 0.1953
# --- tanh result report ---
# train acc, test acc | 0.28458, 0.2746
# --- tanh result report ---
# train acc, test acc | 0.18694, 0.1877
# --- tanh result report ---
# train acc, test acc | 0.23578, 0.2342
# --- tanh result report ---
# train acc, test acc | 0.27898, 0.282
# --- tanh result report ---
# train acc, test acc | 0.24862, 0.2524
# --- tanh result report ---
# train acc, test acc | 0.32324, 0.3191
# --- tanh result report ---
# train acc, test acc | 0.27418, 0.2738
# --- tanh result report ---
# train acc, test acc | 0.29472, 0.2978
# --- tanh result report ---
# train acc, test acc | 0.23558, 0.2385
# --- tanh result report ---
# train acc, test acc | 0.35458, 0.3479
# --- tanh result report ---
# train acc, test acc | 0.2956, 0.2928
# --- tanh result report ---
# train acc, test acc | 0.30408, 0.2978
# --- tanh result report ---
# train acc, test acc | 0.2916, 0.2937
# --- tanh result report ---
# train acc, test acc | 0.27328, 0.2727
# --- tanh result report ---
# train acc, test acc | 0.2614, 0.2604
# --- tanh result report ---
# train acc, test acc | 0.24474, 0.2491
# --- tanh result report ---
# train acc, test acc | 0.22872, 0.2351
# --- tanh result report ---
# train acc, test acc | 0.21184, 0.2179
# --- tanh result report ---
# train acc, test acc | 0.30724, 0.3033
# --- tanh result report ---
# train acc, test acc | 0.28464, 0.2786
# --- tanh result report ---
# train acc, test acc | 0.23586, 0.2375
# --- tanh result report ---
# train acc, test acc | 0.28058, 0.2853
# --- tanh result report ---
# train acc, test acc | 0.24902, 0.2542
# --- tanh result report ---
# train acc, test acc | 0.31028, 0.3106
# --- tanh result report ---
# train acc, test acc | 0.29722, 0.2926
# --- tanh result report ---
# train acc, test acc | 0.27518, 0.2836
# --- tanh result report ---
# train acc, test acc | 0.3099, 0.3092
# --- tanh result report ---
# train acc, test acc | 0.27766, 0.2787
# --- tanh result report ---
# train acc, test acc | 0.28742, 0.2904
# --- tanh result report ---
# train acc, test acc | 0.2844, 0.28
# --- tanh result report ---
# train acc, test acc | 0.25838, 0.2621
# --- tanh result report ---
# train acc, test acc | 0.3064, 0.3006
# --- tanh result report ---
# train acc, test acc | 0.32126, 0.3165
# --- tanh result report ---
# train acc, test acc | 0.27434, 0.2698
# --- tanh result report ---
# train acc, test acc | 0.2669, 0.2724
# --- tanh result report ---
# train acc, test acc | 0.248, 0.2496
# --- tanh result report ---
# train acc, test acc | 0.3518, 0.3531
# --- tanh result report ---
# train acc, test acc | 0.26106, 0.2627
# --- tanh result report ---
# train acc, test acc | 0.25366, 0.2516
# --- tanh result report ---
# train acc, test acc | 0.27914, 0.2809
# --- tanh result report ---
# train acc, test acc | 0.22626, 0.2186
# --- tanh result report ---
# train acc, test acc | 0.31036, 0.3114
# --- tanh result report ---
# train acc, test acc | 0.31156, 0.3093
# --- tanh result report ---
# train acc, test acc | 0.30864, 0.3111
# --- tanh result report ---
# train acc, test acc | 0.28486, 0.279
# --- tanh result report ---
# train acc, test acc | 0.25212, 0.2549
# --- tanh result report ---
# train acc, test acc | 0.29032, 0.2853
# --- tanh result report ---
# train acc, test acc | 0.24836, 0.2448
# --- tanh result report ---
# train acc, test acc | 0.2432, 0.2454
# --- tanh result report ---
# train acc, test acc | 0.24802, 0.2492
# --- tanh result report ---
# train acc, test acc | 0.14996, 0.1507
# --- tanh result report ---
# train acc, test acc | 0.23526, 0.234
# --- tanh result report ---
# train acc, test acc | 0.27906, 0.2784
# --- tanh result report ---
# train acc, test acc | 0.25168, 0.2523
# --- tanh result report ---
# train acc, test acc | 0.33732, 0.3422
# --- tanh result report ---
# train acc, test acc | 0.19994, 0.2019
# --- tanh result report ---
# train acc, test acc | 0.2301, 0.2379
# --- tanh result report ---
# train acc, test acc | 0.26352, 0.2648
# --- tanh result report ---
# train acc, test acc | 0.31484, 0.3128
# --- tanh result report ---
# train acc, test acc | 0.26558, 0.2642
# --- tanh result report ---
# train acc, test acc | 0.25358, 0.2549
# --- tanh result report ---
# train acc, test acc | 0.21288, 0.2142
# --- tanh result report ---
# train acc, test acc | 0.30522, 0.3022
# --- tanh result report ---
# train acc, test acc | 0.21976, 0.2224
# --- tanh result report ---
# train acc, test acc | 0.28032, 0.2833
# --- tanh result report ---
# train acc, test acc | 0.23832, 0.2381
# --- tanh result report ---
# train acc, test acc | 0.30872, 0.3084
# --- tanh result report ---
# train acc, test acc | 0.21588, 0.2236
# --- tanh result report ---
# train acc, test acc | 0.26854, 0.2621
# --- tanh result report ---
# train acc, test acc | 0.20558, 0.2006
# --- tanh result report ---
# train acc, test acc | 0.2607, 0.2614
# --- tanh result report ---
# train acc, test acc | 0.2457, 0.2511
# --- tanh result report ---
# train acc, test acc | 0.3426, 0.336
# --- tanh result report ---
# train acc, test acc | 0.24488, 0.2406
# --- tanh result report ---
# train acc, test acc | 0.30936, 0.3038
# --- tanh result report ---
# train acc, test acc | 0.25222, 0.2572
# --- tanh result report ---
# train acc, test acc | 0.24282, 0.2438
# --- tanh result report ---
# train acc, test acc | 0.29944, 0.2961
# --- tanh result report ---
# train acc, test acc | 0.24766, 0.2524
# --- tanh result report ---
# train acc, test acc | 0.25024, 0.254
# --- tanh result report ---
# train acc, test acc | 0.29214, 0.2901
# --- tanh result report ---
# train acc, test acc | 0.28696, 0.2839
# --- tanh result report ---
# train acc, test acc | 0.28884, 0.2896
# --- tanh result report ---
# train acc, test acc | 0.30522, 0.2995
# --- tanh result report ---
# train acc, test acc | 0.28492, 0.2896
# ==========
#
#
#
# === relu network training start ===
# --- relu result report ---
# train acc, test acc | 0.1273, 0.1281
# --- relu result report ---
# train acc, test acc | 0.24462, 0.2423
# --- relu result report ---
# train acc, test acc | 0.27006, 0.2625
# --- relu result report ---
# train acc, test acc | 0.29028, 0.2871
# --- relu result report ---
# train acc, test acc | 0.29742, 0.3012
# --- relu result report ---
# train acc, test acc | 0.29058, 0.2981
# --- relu result report ---
# train acc, test acc | 0.30758, 0.3084
# --- relu result report ---
# train acc, test acc | 0.29464, 0.2909
# --- relu result report ---
# train acc, test acc | 0.27914, 0.2796
# --- relu result report ---
# train acc, test acc | 0.32548, 0.3289
# --- relu result report ---
# train acc, test acc | 0.27102, 0.2724
# --- relu result report ---
# train acc, test acc | 0.2752, 0.278
# --- relu result report ---
# train acc, test acc | 0.29468, 0.2876
# --- relu result report ---
# train acc, test acc | 0.32112, 0.3202
# --- relu result report ---
# train acc, test acc | 0.29258, 0.2897
# --- relu result report ---
# train acc, test acc | 0.33018, 0.3248
# --- relu result report ---
# train acc, test acc | 0.23982, 0.2394
# --- relu result report ---
# train acc, test acc | 0.22454, 0.2231
# --- relu result report ---
# train acc, test acc | 0.27974, 0.2765
# --- relu result report ---
# train acc, test acc | 0.22398, 0.2192
# --- relu result report ---
# train acc, test acc | 0.31928, 0.3201
# --- relu result report ---
# train acc, test acc | 0.26096, 0.2614
# --- relu result report ---
# train acc, test acc | 0.29266, 0.2922
# --- relu result report ---
# train acc, test acc | 0.31796, 0.3124
# --- relu result report ---
# train acc, test acc | 0.27546, 0.2715
# --- relu result report ---
# train acc, test acc | 0.28404, 0.2816
# --- relu result report ---
# train acc, test acc | 0.29376, 0.2906
# --- relu result report ---
# train acc, test acc | 0.13072, 0.1292
# --- relu result report ---
# train acc, test acc | 0.2672, 0.2699
# --- relu result report ---
# train acc, test acc | 0.28718, 0.2846
# --- relu result report ---
# train acc, test acc | 0.2988, 0.2991
# --- relu result report ---
# train acc, test acc | 0.32572, 0.3267
# --- relu result report ---
# train acc, test acc | 0.18636, 0.1841
# --- relu result report ---
# train acc, test acc | 0.29494, 0.2929
# --- relu result report ---
# train acc, test acc | 0.30374, 0.3091
# --- relu result report ---
# train acc, test acc | 0.27012, 0.2685
# --- relu result report ---
# train acc, test acc | 0.2758, 0.2758
# --- relu result report ---
# train acc, test acc | 0.18156, 0.18
# --- relu result report ---
# train acc, test acc | 0.27856, 0.2803
# --- relu result report ---
# train acc, test acc | 0.29952, 0.2996
# --- relu result report ---
# train acc, test acc | 0.20558, 0.2027
# --- relu result report ---
# train acc, test acc | 0.2511, 0.2535
# --- relu result report ---
# train acc, test acc | 0.27228, 0.2692
# --- relu result report ---
# train acc, test acc | 0.34, 0.3357
# --- relu result report ---
# train acc, test acc | 0.29512, 0.2928
# --- relu result report ---
# train acc, test acc | 0.1955, 0.1973
# --- relu result report ---
# train acc, test acc | 0.25794, 0.2533
# --- relu result report ---
# train acc, test acc | 0.28204, 0.2797
# --- relu result report ---
# train acc, test acc | 0.25538, 0.2602
# --- relu result report ---
# train acc, test acc | 0.32714, 0.3282
# --- relu result report ---
# train acc, test acc | 0.19644, 0.2007
# --- relu result report ---
# train acc, test acc | 0.30332, 0.3012
# --- relu result report ---
# train acc, test acc | 0.28392, 0.2814
# --- relu result report ---
# train acc, test acc | 0.16218, 0.1643
# --- relu result report ---
# train acc, test acc | 0.29566, 0.2912
# --- relu result report ---
# train acc, test acc | 0.3032, 0.3009
# --- relu result report ---
# train acc, test acc | 0.25932, 0.2521
# --- relu result report ---
# train acc, test acc | 0.30682, 0.302
# --- relu result report ---
# train acc, test acc | 0.3213, 0.3151
# --- relu result report ---
# train acc, test acc | 0.301, 0.2972
# --- relu result report ---
# train acc, test acc | 0.21154, 0.2133
# --- relu result report ---
# train acc, test acc | 0.3272, 0.3164
# --- relu result report ---
# train acc, test acc | 0.33946, 0.3361
# --- relu result report ---
# train acc, test acc | 0.23388, 0.2393
# --- relu result report ---
# train acc, test acc | 0.31454, 0.3182
# --- relu result report ---
# train acc, test acc | 0.29788, 0.2928
# --- relu result report ---
# train acc, test acc | 0.18368, 0.1836
# --- relu result report ---
# train acc, test acc | 0.161, 0.1592
# --- relu result report ---
# train acc, test acc | 0.30738, 0.3063
# --- relu result report ---
# train acc, test acc | 0.27266, 0.2649
# --- relu result report ---
# train acc, test acc | 0.25466, 0.2547
# --- relu result report ---
# train acc, test acc | 0.29662, 0.2951
# --- relu result report ---
# train acc, test acc | 0.31398, 0.3202
# --- relu result report ---
# train acc, test acc | 0.249, 0.2461
# --- relu result report ---
# train acc, test acc | 0.20812, 0.2127
# --- relu result report ---
# train acc, test acc | 0.27258, 0.2752
# --- relu result report ---
# train acc, test acc | 0.2549, 0.2587
# --- relu result report ---
# train acc, test acc | 0.23682, 0.2384
# --- relu result report ---
# train acc, test acc | 0.28722, 0.2894
# --- relu result report ---
# train acc, test acc | 0.29588, 0.3002
# --- relu result report ---
# train acc, test acc | 0.31418, 0.3117
# --- relu result report ---
# train acc, test acc | 0.33766, 0.3347
# --- relu result report ---
# train acc, test acc | 0.22074, 0.2237
# --- relu result report ---
# train acc, test acc | 0.25094, 0.247
# --- relu result report ---
# train acc, test acc | 0.30184, 0.3021
# --- relu result report ---
# train acc, test acc | 0.22906, 0.2311
# --- relu result report ---
# train acc, test acc | 0.28026, 0.2761
# --- relu result report ---
# train acc, test acc | 0.27412, 0.2756
# --- relu result report ---
# train acc, test acc | 0.21712, 0.2174
# --- relu result report ---
# train acc, test acc | 0.28668, 0.2787
# --- relu result report ---
# train acc, test acc | 0.25244, 0.2509
# --- relu result report ---
# train acc, test acc | 0.31638, 0.3113
# --- relu result report ---
# train acc, test acc | 0.27768, 0.2736
# --- relu result report ---
# train acc, test acc | 0.23188, 0.2273
# --- relu result report ---
# train acc, test acc | 0.30238, 0.2957
# --- relu result report ---
# train acc, test acc | 0.25126, 0.2523
# --- relu result report ---
# train acc, test acc | 0.3177, 0.3166
# --- relu result report ---
# train acc, test acc | 0.15446, 0.1484
# --- relu result report ---
# train acc, test acc | 0.26374, 0.259
# --- relu result report ---
# train acc, test acc | 0.31114, 0.3128
# ==========
#
#
#
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.09924, 0.0986
# --- leaky result report ---
# train acc, test acc | 0.32572, 0.3232
# --- leaky result report ---
# train acc, test acc | 0.16716, 0.166
# --- leaky result report ---
# train acc, test acc | 0.34198, 0.3424
# --- leaky result report ---
# train acc, test acc | 0.2977, 0.2955
# --- leaky result report ---
# train acc, test acc | 0.25832, 0.2658
# --- leaky result report ---
# train acc, test acc | 0.225, 0.2275
# --- leaky result report ---
# train acc, test acc | 0.29952, 0.2972
# --- leaky result report ---
# train acc, test acc | 0.20978, 0.2085
# --- leaky result report ---
# train acc, test acc | 0.25808, 0.252
# --- leaky result report ---
# train acc, test acc | 0.2443, 0.2437
# --- leaky result report ---
# train acc, test acc | 0.34912, 0.3451
# --- leaky result report ---
# train acc, test acc | 0.25726, 0.2565
# --- leaky result report ---
# train acc, test acc | 0.32902, 0.3232
# --- leaky result report ---
# train acc, test acc | 0.3105, 0.314
# --- leaky result report ---
# train acc, test acc | 0.30292, 0.3063
# --- leaky result report ---
# train acc, test acc | 0.26736, 0.27
# --- leaky result report ---
# train acc, test acc | 0.16026, 0.1566
# --- leaky result report ---
# train acc, test acc | 0.28142, 0.2796
# --- leaky result report ---
# train acc, test acc | 0.31038, 0.3084
# --- leaky result report ---
# train acc, test acc | 0.3156, 0.3116
# --- leaky result report ---
# train acc, test acc | 0.35934, 0.3568
# --- leaky result report ---
# train acc, test acc | 0.11376, 0.1125
# --- leaky result report ---
# train acc, test acc | 0.16066, 0.1608
# --- leaky result report ---
# train acc, test acc | 0.35668, 0.3501
# --- leaky result report ---
# train acc, test acc | 0.25862, 0.2587
# --- leaky result report ---
# train acc, test acc | 0.26356, 0.2637
# --- leaky result report ---
# train acc, test acc | 0.25266, 0.246
# --- leaky result report ---
# train acc, test acc | 0.27934, 0.2831
# --- leaky result report ---
# train acc, test acc | 0.32716, 0.3245
# --- leaky result report ---
# train acc, test acc | 0.2579, 0.2595
# --- leaky result report ---
# train acc, test acc | 0.28226, 0.2829
# --- leaky result report ---
# train acc, test acc | 0.28746, 0.2802
# --- leaky result report ---
# train acc, test acc | 0.25196, 0.257
# --- leaky result report ---
# train acc, test acc | 0.14266, 0.1424
# --- leaky result report ---
# train acc, test acc | 0.19446, 0.195
# --- leaky result report ---
# train acc, test acc | 0.22754, 0.2299
# --- leaky result report ---
# train acc, test acc | 0.32914, 0.3275
# --- leaky result report ---
# train acc, test acc | 0.32142, 0.3135
# --- leaky result report ---
# train acc, test acc | 0.2834, 0.2868
# --- leaky result report ---
# train acc, test acc | 0.21668, 0.2168
# --- leaky result report ---
# train acc, test acc | 0.269, 0.2666
# --- leaky result report ---
# train acc, test acc | 0.25646, 0.2572
# --- leaky result report ---
# train acc, test acc | 0.1634, 0.1603
# --- leaky result report ---
# train acc, test acc | 0.27168, 0.2744
# --- leaky result report ---
# train acc, test acc | 0.30384, 0.2953
# --- leaky result report ---
# train acc, test acc | 0.24004, 0.2443
# --- leaky result report ---
# train acc, test acc | 0.18236, 0.1855
# --- leaky result report ---
# train acc, test acc | 0.19274, 0.1954
# --- leaky result report ---
# train acc, test acc | 0.2951, 0.2909
# --- leaky result report ---
# train acc, test acc | 0.25768, 0.2594
# --- leaky result report ---
# train acc, test acc | 0.19878, 0.1997
# --- leaky result report ---
# train acc, test acc | 0.2911, 0.2908
# --- leaky result report ---
# train acc, test acc | 0.2988, 0.3008
# --- leaky result report ---
# train acc, test acc | 0.35556, 0.3568
# --- leaky result report ---
# train acc, test acc | 0.25698, 0.2586
# --- leaky result report ---
# train acc, test acc | 0.17016, 0.1705
# --- leaky result report ---
# train acc, test acc | 0.32546, 0.3221
# --- leaky result report ---
# train acc, test acc | 0.25308, 0.2541
# --- leaky result report ---
# train acc, test acc | 0.33136, 0.3285
# --- leaky result report ---
# train acc, test acc | 0.24248, 0.2412
# --- leaky result report ---
# train acc, test acc | 0.2986, 0.2944
# --- leaky result report ---
# train acc, test acc | 0.32822, 0.3272
# --- leaky result report ---
# train acc, test acc | 0.33386, 0.3298
# --- leaky result report ---
# train acc, test acc | 0.31222, 0.3092
# --- leaky result report ---
# train acc, test acc | 0.22552, 0.227
# --- leaky result report ---
# train acc, test acc | 0.31392, 0.3176
# --- leaky result report ---
# train acc, test acc | 0.37496, 0.3775
# --- leaky result report ---
# train acc, test acc | 0.31494, 0.3218
# --- leaky result report ---
# train acc, test acc | 0.21346, 0.2131
# --- leaky result report ---
# train acc, test acc | 0.211, 0.2151
# --- leaky result report ---
# train acc, test acc | 0.27102, 0.2735
# --- leaky result report ---
# train acc, test acc | 0.2638, 0.2631
# --- leaky result report ---
# train acc, test acc | 0.16744, 0.1682
# --- leaky result report ---
# train acc, test acc | 0.17702, 0.1779
# --- leaky result report ---
# train acc, test acc | 0.29392, 0.2889
# --- leaky result report ---
# train acc, test acc | 0.33496, 0.3313
# --- leaky result report ---
# train acc, test acc | 0.29244, 0.2968
# --- leaky result report ---
# train acc, test acc | 0.32186, 0.3196
# --- leaky result report ---
# train acc, test acc | 0.26106, 0.2625
# --- leaky result report ---
# train acc, test acc | 0.31546, 0.3153
# --- leaky result report ---
# train acc, test acc | 0.25454, 0.2548
# --- leaky result report ---
# train acc, test acc | 0.34924, 0.345
# --- leaky result report ---
# train acc, test acc | 0.2546, 0.2513
# --- leaky result report ---
# train acc, test acc | 0.31696, 0.3174
# --- leaky result report ---
# train acc, test acc | 0.28988, 0.2844
# --- leaky result report ---
# train acc, test acc | 0.36834, 0.369
# --- leaky result report ---
# train acc, test acc | 0.3127, 0.3151
# --- leaky result report ---
# train acc, test acc | 0.27986, 0.2782
# --- leaky result report ---
# train acc, test acc | 0.27248, 0.2759
# --- leaky result report ---
# train acc, test acc | 0.18764, 0.1889
# --- leaky result report ---
# train acc, test acc | 0.27124, 0.2709
# --- leaky result report ---
# train acc, test acc | 0.2657, 0.2622
# --- leaky result report ---
# train acc, test acc | 0.25908, 0.2559
# --- leaky result report ---
# train acc, test acc | 0.33004, 0.3301
# --- leaky result report ---
# train acc, test acc | 0.23174, 0.2264
# --- leaky result report ---
# train acc, test acc | 0.28216, 0.272
# --- leaky result report ---
# train acc, test acc | 0.34688, 0.343
# --- leaky result report ---
# train acc, test acc | 0.29474, 0.2908
# --- leaky result report ---
# train acc, test acc | 0.33328, 0.325
# ==========

# %%
for k, v in output_dict.items():
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
plt.ylim([0.0, 1.0])
plt.legend(loc='lower right', prop={'size':7})
plt.grid()
