# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
test_dict = {}
train_dict = {}
root_path = '../datasets/cifar-10-batches-py/'


def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

accepted_keys = [b'labels', b'data'] ## select keys from [b'batch_label', b'labels', b'data', b'filenames']
for dir in os.listdir(root_path):
    if dir == 'batches.meta':
        pass
    elif dir == 'test_batch':
        test_batch = unpickle(os.path.join(root_path, dir))
        test_dict.update((k,np.array(v)) for k,v in test_batch.items() if k in accepted_keys)
    else:
        train_batch = unpickle(os.path.join(root_path, dir))
        if not train_dict:
            train_dict.update((k,np.array(v)) for k,v in train_batch.items() if k in accepted_keys)
        else:
            for key in accepted_keys:
                train_dict[key] = np.concatenate((train_dict[key], train_batch[key]), axis=0)


## CIFAR data's shape are (N, H*W*C). 
## If you want to convert them into numpy-standard (N, H, W, C) shape, run following codes.
def numpy2rgb(arr: np.ndarray) -> np.ndarray:
    batch_size = len(arr)
    arr = arr.reshape(batch_size, 3, 32, 32).transpose(0,2,3,1)
    
    return arr


train_dict[b'data'] = numpy2rgb(train_dict[b'data'])
test_dict[b'data'] = numpy2rgb(test_dict[b'data'])

# %%
def normalize(data: np.ndarray, mean: int=None, std: int=None) -> np.ndarray:
    if mean == None:
        mean = np.mean(data)
        
    if std == None:
        std = np.std(data)
    
    data = (data - mean) / std
    return data

# %%
x_train, t_train = normalize(train_dict[b'data']), train_dict[b'labels']
x_test, t_test = normalize(test_dict[b'data']), test_dict[b'labels']

print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 2.09341038199596
# (50000,)

# %%
print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 2.09341038199596
# (50000,)

# %%
network_dict = {
                'leaky-0.2': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='relu', weight_decay_lambda=0.1, use_dropout=True, dropout_ration=0.2, use_batchnorm=True),
                'leaky-0.5': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='relu', weight_decay_lambda=0.1, use_dropout=True, dropout_ration=0.5, use_batchnorm=True),
                'leaky-0.7': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='relu', weight_decay_lambda=0.1, use_dropout=True, dropout_ration=0.7, use_batchnorm=True),c
                }
# Out:
#   Cell In[25], line 4
#     'leaky-0.7': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='relu', weight_decay_lambda=0.1, use_dropout=True, dropout_ration=0.7, use_batchnorm=True),c
#                                                                                                                                                                                                                                 ^
# SyntaxError: ':' expected after dictionary key

# %%
network_dict['leaky'].params.keys()
# Out:
# dict_keys(['W1', 'b1', 'W2', 'b2', 'gamma1', 'beta1'])

# %%
# 하이퍼 파라메터
iters_num = 50_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.17642, 0.1779
# --- leaky result report ---
# train acc, test acc | 0.37784, 0.3741
# --- leaky result report ---
# train acc, test acc | 0.38664, 0.3855
# --- leaky result report ---
# train acc, test acc | 0.37946, 0.3757
# --- leaky result report ---
# train acc, test acc | 0.3407, 0.3392
# --- leaky result report ---
# train acc, test acc | 0.39934, 0.397
# --- leaky result report ---
# train acc, test acc | 0.38432, 0.3865
# --- leaky result report ---
# train acc, test acc | 0.39378, 0.3921
# --- leaky result report ---
# train acc, test acc | 0.3711, 0.3682
# --- leaky result report ---
# train acc, test acc | 0.38144, 0.3796
# --- leaky result report ---
# train acc, test acc | 0.37772, 0.381
# --- leaky result report ---
# train acc, test acc | 0.3809, 0.3791
# --- leaky result report ---
# train acc, test acc | 0.37846, 0.3771
# --- leaky result report ---
# train acc, test acc | 0.38184, 0.3807
# --- leaky result report ---
# train acc, test acc | 0.3772, 0.3715
# --- leaky result report ---
# train acc, test acc | 0.36626, 0.3644
# --- leaky result report ---
# train acc, test acc | 0.38784, 0.3888
# --- leaky result report ---
# train acc, test acc | 0.3623, 0.362
# --- leaky result report ---
# train acc, test acc | 0.37658, 0.3777
# --- leaky result report ---
# train acc, test acc | 0.37476, 0.3675
# --- leaky result report ---
# train acc, test acc | 0.36774, 0.3669
# --- leaky result report ---
# train acc, test acc | 0.39072, 0.3908
# --- leaky result report ---
# train acc, test acc | 0.37902, 0.3801
# --- leaky result report ---
# train acc, test acc | 0.40188, 0.3975
# --- leaky result report ---
# train acc, test acc | 0.38444, 0.39
# --- leaky result report ---
# train acc, test acc | 0.39022, 0.3837
# --- leaky result report ---
# train acc, test acc | 0.3894, 0.3931
# --- leaky result report ---
# train acc, test acc | 0.39128, 0.3884
# --- leaky result report ---
# train acc, test acc | 0.38782, 0.3846
# --- leaky result report ---
# train acc, test acc | 0.38618, 0.3736
# --- leaky result report ---
# train acc, test acc | 0.38622, 0.3871
# --- leaky result report ---
# train acc, test acc | 0.35756, 0.3559
# --- leaky result report ---
# train acc, test acc | 0.37618, 0.3717
# --- leaky result report ---
# train acc, test acc | 0.39496, 0.3962
# --- leaky result report ---
# train acc, test acc | 0.39344, 0.3961
# --- leaky result report ---
# train acc, test acc | 0.3632, 0.3642
# --- leaky result report ---
# train acc, test acc | 0.3583, 0.3551
# --- leaky result report ---
# train acc, test acc | 0.3795, 0.3813
# --- leaky result report ---
# train acc, test acc | 0.3901, 0.3866
# --- leaky result report ---
# train acc, test acc | 0.38488, 0.3791
# --- leaky result report ---
# train acc, test acc | 0.39282, 0.3916
# --- leaky result report ---
# train acc, test acc | 0.36818, 0.3684
# --- leaky result report ---
# train acc, test acc | 0.3892, 0.3852
# --- leaky result report ---
# train acc, test acc | 0.38576, 0.3877
# --- leaky result report ---
# train acc, test acc | 0.39564, 0.3942
# --- leaky result report ---
# train acc, test acc | 0.35188, 0.3501
# --- leaky result report ---
# train acc, test acc | 0.37616, 0.3697
# --- leaky result report ---
# train acc, test acc | 0.38514, 0.3814
# --- leaky result report ---
# train acc, test acc | 0.38564, 0.3883
# --- leaky result report ---
# train acc, test acc | 0.37252, 0.3685
# --- leaky result report ---
# train acc, test acc | 0.38328, 0.3809
# --- leaky result report ---
# train acc, test acc | 0.37178, 0.3753
# --- leaky result report ---
# train acc, test acc | 0.38634, 0.39
# --- leaky result report ---
# train acc, test acc | 0.3734, 0.3649
# --- leaky result report ---
# train acc, test acc | 0.38366, 0.3807
# --- leaky result report ---
# train acc, test acc | 0.37934, 0.3748
# --- leaky result report ---
# train acc, test acc | 0.39548, 0.3935
# --- leaky result report ---
# train acc, test acc | 0.38356, 0.3859
# --- leaky result report ---
# train acc, test acc | 0.37536, 0.3687
# --- leaky result report ---
# train acc, test acc | 0.35034, 0.3483
# --- leaky result report ---
# train acc, test acc | 0.37456, 0.3753
# --- leaky result report ---
# train acc, test acc | 0.3831, 0.3824
# --- leaky result report ---
# train acc, test acc | 0.39492, 0.3947
# --- leaky result report ---
# train acc, test acc | 0.38446, 0.3767
# --- leaky result report ---
# train acc, test acc | 0.38468, 0.3796
# --- leaky result report ---
# train acc, test acc | 0.38494, 0.381
# --- leaky result report ---
# train acc, test acc | 0.38302, 0.3762
# --- leaky result report ---
# train acc, test acc | 0.36996, 0.37
# --- leaky result report ---
# train acc, test acc | 0.3798, 0.3734
# --- leaky result report ---
# train acc, test acc | 0.37904, 0.3842
# --- leaky result report ---
# train acc, test acc | 0.38286, 0.3902
# --- leaky result report ---
# train acc, test acc | 0.36824, 0.3673
# --- leaky result report ---
# train acc, test acc | 0.38868, 0.3859
# --- leaky result report ---
# train acc, test acc | 0.39162, 0.3858
# --- leaky result report ---
# train acc, test acc | 0.37752, 0.3748
# --- leaky result report ---
# train acc, test acc | 0.38712, 0.3828
# --- leaky result report ---
# train acc, test acc | 0.36718, 0.3684
# --- leaky result report ---
# train acc, test acc | 0.36346, 0.3647
# --- leaky result report ---
# train acc, test acc | 0.3883, 0.3786
# --- leaky result report ---
# train acc, test acc | 0.37488, 0.3718
# --- leaky result report ---
# train acc, test acc | 0.37808, 0.3774
# --- leaky result report ---
# train acc, test acc | 0.38452, 0.3847
# --- leaky result report ---
# train acc, test acc | 0.39376, 0.3952
# --- leaky result report ---
# train acc, test acc | 0.39342, 0.3965
# --- leaky result report ---
# train acc, test acc | 0.37876, 0.377
# --- leaky result report ---
# train acc, test acc | 0.38606, 0.3849
# --- leaky result report ---
# train acc, test acc | 0.35964, 0.3597
# --- leaky result report ---
# train acc, test acc | 0.36792, 0.3659
# --- leaky result report ---
# train acc, test acc | 0.36246, 0.3626
# --- leaky result report ---
# train acc, test acc | 0.38086, 0.3816
# --- leaky result report ---
# train acc, test acc | 0.38478, 0.3759
# --- leaky result report ---
# train acc, test acc | 0.38692, 0.3828
# --- leaky result report ---
# train acc, test acc | 0.38404, 0.3829
# --- leaky result report ---
# train acc, test acc | 0.38006, 0.371
# --- leaky result report ---
# train acc, test acc | 0.37682, 0.3811
# --- leaky result report ---
# train acc, test acc | 0.37564, 0.3811
# --- leaky result report ---
# train acc, test acc | 0.39124, 0.3897
# --- leaky result report ---
# train acc, test acc | 0.3929, 0.3872
# --- leaky result report ---
# train acc, test acc | 0.38644, 0.3794
# --- leaky result report ---
# train acc, test acc | 0.37804, 0.3777
# ==========

# %%
for k, v in output_dict.items():
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
plt.ylim([0.0, 1.0])
plt.legend(loc='lower right', prop={'size':7})
plt.grid()
