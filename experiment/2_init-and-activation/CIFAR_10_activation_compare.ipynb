# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
# from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
test_dict = {}
train_dict = {}
root_path = '../datasets/cifar-10-batches-py/'


def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

accepted_keys = [b'labels', b'data'] ## select keys from [b'batch_label', b'labels', b'data', b'filenames']
for dir in os.listdir(root_path):
    if dir == 'batches.meta':
        pass
    elif dir == 'test_batch':
        test_batch = unpickle(os.path.join(root_path, dir))
        test_dict.update((k,np.array(v)) for k,v in test_batch.items() if k in accepted_keys)
    else:
        train_batch = unpickle(os.path.join(root_path, dir))
        if not train_dict:
            train_dict.update((k,np.array(v)) for k,v in train_batch.items() if k in accepted_keys)
        else:
            for key in accepted_keys:
                train_dict[key] = np.concatenate((train_dict[key], train_batch[key]), axis=0)


## CIFAR data's shape are (N, H*W*C). 
## If you want to convert them into numpy-standard (N, H, W, C) shape, run following codes.
def numpy2rgb(arr: np.ndarray) -> np.ndarray:
    batch_size = len(arr)
    arr = arr.reshape(batch_size, 3, 32, 32).transpose(0,2,3,1)
    
    return arr


train_dict[b'data'] = numpy2rgb(train_dict[b'data'])
test_dict[b'data'] = numpy2rgb(test_dict[b'data'])

# %%
x_train, t_train = train_dict[b'data'] / 255.0, train_dict[b'labels']
x_test, t_test = test_dict[b'data'] / 255.0, test_dict[b'labels']

print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 1.0
# (50000,)

# %%
t_train[:100]
# Out:
# array([6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6, 4, 3,
#        6, 6, 2, 6, 3, 5, 4, 0, 0, 9, 1, 3, 4, 0, 3, 7, 3, 3, 5, 2, 2, 7,
#        1, 1, 1, 2, 2, 0, 9, 5, 7, 9, 2, 2, 5, 2, 4, 3, 1, 1, 8, 2, 1, 1,
#        4, 9, 7, 8, 5, 9, 6, 7, 3, 1, 9, 0, 3, 1, 3, 5, 4, 5, 7, 7, 4, 7,
#        9, 4, 2, 3, 8, 0, 1, 6, 1, 1, 4, 1])

# %%
network_dict = {
                'sigmoid-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
                'tanh-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
                'relu-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
                'leaky-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
                }
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 network_dict = {
# ----> 2                 'sigmoid-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
#       3                 'tanh-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
#       4                 'relu-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
#       5                 'leaky-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='he', weight_init_std=0.01),
#       6                 }
#
# File ~/OneDrive_korea/2_My-Programming/0_DL_from_scratch/experiment/2_init-and-activation/multi_layer_net_extend.py:102, in MultiLayerNetExtend.__init__(self, input_size, hidden_size_list, output_size, activation, weight_init_std, weight_decay_lambda, use_dropout, dropout_ration, use_batchnorm)
#      99     self.params['beta' + str(idx)] = np.zeros(hidden_size_list[idx-1])
#     100     self.layers['BatchNorm' + str(idx)] = BatchNormalization(self.params['gamma' + str(idx)], self.params['beta' + str(idx)])
# --> 102 self.layers['Activation_function' + str(idx)] = activation_layer[activation]()
#     104 if self.use_dropout:
#     105     self.layers['Dropout' + str(idx)] = Dropout(dropout_ration)
#
# KeyError: 'he'

# %%
# 하이퍼 파라메터
iters_num = 50_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === step network training start ===
# --- step result report ---
# train acc, test acc | 0.10006, 0.1002
# --- step result report ---
# train acc, test acc | 0.28158, 0.2859
# --- step result report ---
# train acc, test acc | 0.2852, 0.2835
# --- step result report ---
# train acc, test acc | 0.28736, 0.2835
# --- step result report ---
# train acc, test acc | 0.2962, 0.2935
# --- step result report ---
# train acc, test acc | 0.29442, 0.2922
# --- step result report ---
# train acc, test acc | 0.29734, 0.2931
# --- step result report ---
# train acc, test acc | 0.29324, 0.2889
# --- step result report ---
# train acc, test acc | 0.29612, 0.2922
# --- step result report ---
# train acc, test acc | 0.2925, 0.2874
# --- step result report ---
# train acc, test acc | 0.29516, 0.2899
# --- step result report ---
# train acc, test acc | 0.29922, 0.2946
# --- step result report ---
# train acc, test acc | 0.29432, 0.291
# --- step result report ---
# train acc, test acc | 0.30084, 0.2929
# --- step result report ---
# train acc, test acc | 0.29366, 0.2913
# --- step result report ---
# train acc, test acc | 0.2995, 0.2966
# --- step result report ---
# train acc, test acc | 0.2956, 0.2919
# --- step result report ---
# train acc, test acc | 0.30174, 0.2955
# --- step result report ---
# train acc, test acc | 0.29432, 0.2915
# --- step result report ---
# train acc, test acc | 0.29522, 0.2936
# --- step result report ---
# train acc, test acc | 0.28778, 0.2808
# --- step result report ---
# train acc, test acc | 0.29286, 0.2874
# --- step result report ---
# train acc, test acc | 0.29952, 0.2932
# --- step result report ---
# train acc, test acc | 0.29812, 0.29
# --- step result report ---
# train acc, test acc | 0.29034, 0.2879
# --- step result report ---
# train acc, test acc | 0.29996, 0.2905
# --- step result report ---
# train acc, test acc | 0.29472, 0.2951
# --- step result report ---
# train acc, test acc | 0.29268, 0.2915
# --- step result report ---
# train acc, test acc | 0.30104, 0.299
# --- step result report ---
# train acc, test acc | 0.29882, 0.2961
# --- step result report ---
# train acc, test acc | 0.29178, 0.2839
# --- step result report ---
# train acc, test acc | 0.2933, 0.2903
# --- step result report ---
# train acc, test acc | 0.30054, 0.293
# --- step result report ---
# train acc, test acc | 0.30044, 0.2984
# --- step result report ---
# train acc, test acc | 0.30028, 0.2973
# --- step result report ---
# train acc, test acc | 0.28904, 0.2827
# --- step result report ---
# train acc, test acc | 0.30046, 0.2939
# --- step result report ---
# train acc, test acc | 0.30066, 0.2933
# --- step result report ---
# train acc, test acc | 0.29898, 0.2938
# --- step result report ---
# train acc, test acc | 0.29934, 0.2959
# --- step result report ---
# train acc, test acc | 0.29984, 0.2946
# --- step result report ---
# train acc, test acc | 0.2994, 0.2933
# --- step result report ---
# train acc, test acc | 0.30194, 0.296
# --- step result report ---
# train acc, test acc | 0.30084, 0.2951
# --- step result report ---
# train acc, test acc | 0.29894, 0.295
# --- step result report ---
# train acc, test acc | 0.29606, 0.2872
# --- step result report ---
# train acc, test acc | 0.29818, 0.2914
# --- step result report ---
# train acc, test acc | 0.29812, 0.2961
# --- step result report ---
# train acc, test acc | 0.29772, 0.2885
# --- step result report ---
# train acc, test acc | 0.29722, 0.2913
# --- step result report ---
# train acc, test acc | 0.29268, 0.2854
# --- step result report ---
# train acc, test acc | 0.29764, 0.2947
# --- step result report ---
# train acc, test acc | 0.30032, 0.2976
# --- step result report ---
# train acc, test acc | 0.29782, 0.2919
# --- step result report ---
# train acc, test acc | 0.28408, 0.2808
# --- step result report ---
# train acc, test acc | 0.2977, 0.297
# --- step result report ---
# train acc, test acc | 0.29704, 0.2946
# --- step result report ---
# train acc, test acc | 0.3003, 0.2984
# --- step result report ---
# train acc, test acc | 0.30056, 0.2962
# --- step result report ---
# train acc, test acc | 0.30254, 0.2989
# --- step result report ---
# train acc, test acc | 0.30016, 0.2965
# --- step result report ---
# train acc, test acc | 0.29768, 0.2933
# --- step result report ---
# train acc, test acc | 0.30172, 0.3022
# --- step result report ---
# train acc, test acc | 0.30058, 0.2954
# --- step result report ---
# train acc, test acc | 0.29774, 0.2933
# --- step result report ---
# train acc, test acc | 0.30036, 0.2915
# --- step result report ---
# train acc, test acc | 0.30072, 0.2975
# --- step result report ---
# train acc, test acc | 0.29858, 0.294
# --- step result report ---
# train acc, test acc | 0.30074, 0.2925
# --- step result report ---
# train acc, test acc | 0.3002, 0.2956
# --- step result report ---
# train acc, test acc | 0.29734, 0.288
# --- step result report ---
# train acc, test acc | 0.30012, 0.2955
# --- step result report ---
# train acc, test acc | 0.29172, 0.2859
# --- step result report ---
# train acc, test acc | 0.29848, 0.2917
# --- step result report ---
# train acc, test acc | 0.29564, 0.2916
# --- step result report ---
# train acc, test acc | 0.2973, 0.2963
# --- step result report ---
# train acc, test acc | 0.30168, 0.2988
# --- step result report ---
# train acc, test acc | 0.2993, 0.2989
# --- step result report ---
# train acc, test acc | 0.29114, 0.2881
# --- step result report ---
# train acc, test acc | 0.29572, 0.2899
# --- step result report ---
# train acc, test acc | 0.29366, 0.29
# --- step result report ---
# train acc, test acc | 0.29522, 0.2921
# --- step result report ---
# train acc, test acc | 0.2967, 0.2866
# --- step result report ---
# train acc, test acc | 0.2951, 0.2919
# --- step result report ---
# train acc, test acc | 0.29468, 0.286
# --- step result report ---
# train acc, test acc | 0.29918, 0.2946
# --- step result report ---
# train acc, test acc | 0.30082, 0.2924
# --- step result report ---
# train acc, test acc | 0.29664, 0.2918
# --- step result report ---
# train acc, test acc | 0.29468, 0.2902
# --- step result report ---
# train acc, test acc | 0.3007, 0.2919
# --- step result report ---
# train acc, test acc | 0.30056, 0.2921
# --- step result report ---
# train acc, test acc | 0.29848, 0.2958
# --- step result report ---
# train acc, test acc | 0.30284, 0.2956
# --- step result report ---
# train acc, test acc | 0.30378, 0.2967
# --- step result report ---
# train acc, test acc | 0.29998, 0.2944
# --- step result report ---
# train acc, test acc | 0.29208, 0.2875
# --- step result report ---
# train acc, test acc | 0.2996, 0.2981
# --- step result report ---
# train acc, test acc | 0.29516, 0.2865
# --- step result report ---
# train acc, test acc | 0.29784, 0.2938
# --- step result report ---
# train acc, test acc | 0.29772, 0.2914
# ==========
#
#
#
# === sigmoid network training start ===
# --- sigmoid result report ---
# train acc, test acc | 0.1, 0.1
# --- sigmoid result report ---
# train acc, test acc | 0.28994, 0.2886
# --- sigmoid result report ---
# train acc, test acc | 0.3334, 0.3325
# --- sigmoid result report ---
# train acc, test acc | 0.36788, 0.3708
# --- sigmoid result report ---
# train acc, test acc | 0.37254, 0.3726
# --- sigmoid result report ---
# train acc, test acc | 0.38686, 0.3907
# --- sigmoid result report ---
# train acc, test acc | 0.41386, 0.4117
# --- sigmoid result report ---
# train acc, test acc | 0.40356, 0.3996
# --- sigmoid result report ---
# train acc, test acc | 0.43368, 0.429
# --- sigmoid result report ---
# train acc, test acc | 0.43756, 0.4329
# --- sigmoid result report ---
# train acc, test acc | 0.43794, 0.4298
# --- sigmoid result report ---
# train acc, test acc | 0.44842, 0.436
# --- sigmoid result report ---
# train acc, test acc | 0.45354, 0.4451
# --- sigmoid result report ---
# train acc, test acc | 0.46474, 0.4521
# --- sigmoid result report ---
# train acc, test acc | 0.4726, 0.4585
# --- sigmoid result report ---
# train acc, test acc | 0.4773, 0.4646
# --- sigmoid result report ---
# train acc, test acc | 0.47326, 0.4547
# --- sigmoid result report ---
# train acc, test acc | 0.48472, 0.4679
# --- sigmoid result report ---
# train acc, test acc | 0.48846, 0.466
# --- sigmoid result report ---
# train acc, test acc | 0.47194, 0.4553
# --- sigmoid result report ---
# train acc, test acc | 0.49892, 0.4729
# --- sigmoid result report ---
# train acc, test acc | 0.50426, 0.48
# --- sigmoid result report ---
# train acc, test acc | 0.50544, 0.4744
# --- sigmoid result report ---
# train acc, test acc | 0.51186, 0.4857
# --- sigmoid result report ---
# train acc, test acc | 0.50842, 0.4783
# --- sigmoid result report ---
# train acc, test acc | 0.50282, 0.4741
# --- sigmoid result report ---
# train acc, test acc | 0.52338, 0.491
# --- sigmoid result report ---
# train acc, test acc | 0.51818, 0.4807
# --- sigmoid result report ---
# train acc, test acc | 0.52838, 0.4907
# --- sigmoid result report ---
# train acc, test acc | 0.51596, 0.4821
# --- sigmoid result report ---
# train acc, test acc | 0.52702, 0.4922
# --- sigmoid result report ---
# train acc, test acc | 0.53124, 0.4914
# --- sigmoid result report ---
# train acc, test acc | 0.5388, 0.4997
# --- sigmoid result report ---
# train acc, test acc | 0.53798, 0.4961
# --- sigmoid result report ---
# train acc, test acc | 0.5433, 0.4951
# --- sigmoid result report ---
# train acc, test acc | 0.51662, 0.4732
# --- sigmoid result report ---
# train acc, test acc | 0.5485, 0.5033
# --- sigmoid result report ---
# train acc, test acc | 0.5435, 0.4948
# --- sigmoid result report ---
# train acc, test acc | 0.5519, 0.5027
# --- sigmoid result report ---
# train acc, test acc | 0.55012, 0.4976
# --- sigmoid result report ---
# train acc, test acc | 0.55904, 0.505
# --- sigmoid result report ---
# train acc, test acc | 0.55374, 0.5037
# --- sigmoid result report ---
# train acc, test acc | 0.55948, 0.4997
# --- sigmoid result report ---
# train acc, test acc | 0.55796, 0.5038
# --- sigmoid result report ---
# train acc, test acc | 0.56108, 0.5017
# --- sigmoid result report ---
# train acc, test acc | 0.56408, 0.5028
# --- sigmoid result report ---
# train acc, test acc | 0.56462, 0.5023
# --- sigmoid result report ---
# train acc, test acc | 0.568, 0.5054
# --- sigmoid result report ---
# train acc, test acc | 0.56696, 0.5048
# --- sigmoid result report ---
# train acc, test acc | 0.57008, 0.5015
# --- sigmoid result report ---
# train acc, test acc | 0.57832, 0.5059
# --- sigmoid result report ---
# train acc, test acc | 0.56218, 0.4953
# --- sigmoid result report ---
# train acc, test acc | 0.57412, 0.4999
# --- sigmoid result report ---
# train acc, test acc | 0.57468, 0.5008
# --- sigmoid result report ---
# train acc, test acc | 0.57176, 0.4921
# --- sigmoid result report ---
# train acc, test acc | 0.59018, 0.5074
# --- sigmoid result report ---
# train acc, test acc | 0.59318, 0.5112
# --- sigmoid result report ---
# train acc, test acc | 0.58866, 0.5051
# --- sigmoid result report ---
# train acc, test acc | 0.56778, 0.49
# --- sigmoid result report ---
# train acc, test acc | 0.59488, 0.5135
# --- sigmoid result report ---
# train acc, test acc | 0.5797, 0.5029
# --- sigmoid result report ---
# train acc, test acc | 0.59128, 0.5054
# --- sigmoid result report ---
# train acc, test acc | 0.58784, 0.5009
# --- sigmoid result report ---
# train acc, test acc | 0.58758, 0.5045
# --- sigmoid result report ---
# train acc, test acc | 0.59826, 0.5094
# --- sigmoid result report ---
# train acc, test acc | 0.5995, 0.5032
# --- sigmoid result report ---
# train acc, test acc | 0.59574, 0.5131
# --- sigmoid result report ---
# train acc, test acc | 0.5843, 0.499
# --- sigmoid result report ---
# train acc, test acc | 0.59772, 0.506
# --- sigmoid result report ---
# train acc, test acc | 0.59078, 0.5035
# --- sigmoid result report ---
# train acc, test acc | 0.6058, 0.5089
# --- sigmoid result report ---
# train acc, test acc | 0.61328, 0.5063
# --- sigmoid result report ---
# train acc, test acc | 0.60504, 0.5057
# --- sigmoid result report ---
# train acc, test acc | 0.60352, 0.5017
# --- sigmoid result report ---
# train acc, test acc | 0.61284, 0.5099
# --- sigmoid result report ---
# train acc, test acc | 0.60324, 0.4962
# --- sigmoid result report ---
# train acc, test acc | 0.60222, 0.5004
# --- sigmoid result report ---
# train acc, test acc | 0.60242, 0.5042
# --- sigmoid result report ---
# train acc, test acc | 0.60794, 0.5032
# --- sigmoid result report ---
# train acc, test acc | 0.6012, 0.4995
# --- sigmoid result report ---
# train acc, test acc | 0.6064, 0.4973
# --- sigmoid result report ---
# train acc, test acc | 0.61726, 0.5057
# --- sigmoid result report ---
# train acc, test acc | 0.627, 0.5101
# --- sigmoid result report ---
# train acc, test acc | 0.61402, 0.5096
# --- sigmoid result report ---
# train acc, test acc | 0.62878, 0.5128
# --- sigmoid result report ---
# train acc, test acc | 0.62648, 0.5058
# --- sigmoid result report ---
# train acc, test acc | 0.61654, 0.4971
# --- sigmoid result report ---
# train acc, test acc | 0.63054, 0.5104
# --- sigmoid result report ---
# train acc, test acc | 0.60068, 0.4818
# --- sigmoid result report ---
# train acc, test acc | 0.61216, 0.4962
# --- sigmoid result report ---
# train acc, test acc | 0.6241, 0.5023
# --- sigmoid result report ---
# train acc, test acc | 0.62814, 0.5068
# --- sigmoid result report ---
# train acc, test acc | 0.63766, 0.5101
# --- sigmoid result report ---
# train acc, test acc | 0.63356, 0.5121
# --- sigmoid result report ---
# train acc, test acc | 0.64584, 0.508
# --- sigmoid result report ---
# train acc, test acc | 0.63634, 0.5021
# --- sigmoid result report ---
# train acc, test acc | 0.6407, 0.5102
# --- sigmoid result report ---
# train acc, test acc | 0.63592, 0.5065
# --- sigmoid result report ---
# train acc, test acc | 0.6519, 0.5135
# --- sigmoid result report ---
# train acc, test acc | 0.6391, 0.5098
# ==========
#
#
#
# === tanh network training start ===
# --- tanh result report ---
# train acc, test acc | 0.1122, 0.1122
# --- tanh result report ---
# train acc, test acc | 0.35602, 0.354
# --- tanh result report ---
# train acc, test acc | 0.39564, 0.393
# --- tanh result report ---
# train acc, test acc | 0.38838, 0.3784
# --- tanh result report ---
# train acc, test acc | 0.4083, 0.4032
# --- tanh result report ---
# train acc, test acc | 0.43854, 0.4288
# --- tanh result report ---
# train acc, test acc | 0.44618, 0.4366
# --- tanh result report ---
# train acc, test acc | 0.44496, 0.4274
# --- tanh result report ---
# train acc, test acc | 0.4662, 0.4531
# --- tanh result report ---
# train acc, test acc | 0.471, 0.4544
# --- tanh result report ---
# train acc, test acc | 0.48034, 0.4528
# --- tanh result report ---
# train acc, test acc | 0.4697, 0.4455
# --- tanh result report ---
# train acc, test acc | 0.49256, 0.4614
# --- tanh result report ---
# train acc, test acc | 0.47986, 0.4549
# --- tanh result report ---
# train acc, test acc | 0.50862, 0.472
# --- tanh result report ---
# train acc, test acc | 0.5124, 0.4751
# --- tanh result report ---
# train acc, test acc | 0.5011, 0.466
# --- tanh result report ---
# train acc, test acc | 0.50998, 0.4706
# --- tanh result report ---
# train acc, test acc | 0.51952, 0.4814
# --- tanh result report ---
# train acc, test acc | 0.52026, 0.4731
# --- tanh result report ---
# train acc, test acc | 0.51928, 0.4654
# --- tanh result report ---
# train acc, test acc | 0.53522, 0.487
# --- tanh result report ---
# train acc, test acc | 0.51962, 0.4721
# --- tanh result report ---
# train acc, test acc | 0.5317, 0.4828
# --- tanh result report ---
# train acc, test acc | 0.53292, 0.4806
# --- tanh result report ---
# train acc, test acc | 0.5202, 0.4662
# --- tanh result report ---
# train acc, test acc | 0.51444, 0.4579
# --- tanh result report ---
# train acc, test acc | 0.52124, 0.4648
# --- tanh result report ---
# train acc, test acc | 0.54058, 0.4764
# --- tanh result report ---
# train acc, test acc | 0.5535, 0.4847
# --- tanh result report ---
# train acc, test acc | 0.5615, 0.4864
# --- tanh result report ---
# train acc, test acc | 0.54924, 0.4765
# --- tanh result report ---
# train acc, test acc | 0.54108, 0.4745
# --- tanh result report ---
# train acc, test acc | 0.56326, 0.4955
# --- tanh result report ---
# train acc, test acc | 0.53768, 0.466
# --- tanh result report ---
# train acc, test acc | 0.55134, 0.4693
# --- tanh result report ---
# train acc, test acc | 0.57004, 0.4881
# --- tanh result report ---
# train acc, test acc | 0.5464, 0.4682
# --- tanh result report ---
# train acc, test acc | 0.54282, 0.464
# --- tanh result report ---
# train acc, test acc | 0.57854, 0.4864
# --- tanh result report ---
# train acc, test acc | 0.5575, 0.4781
# --- tanh result report ---
# train acc, test acc | 0.57798, 0.4869
# --- tanh result report ---
# train acc, test acc | 0.58312, 0.4915
# --- tanh result report ---
# train acc, test acc | 0.59154, 0.4916
# --- tanh result report ---
# train acc, test acc | 0.58878, 0.485
# --- tanh result report ---
# train acc, test acc | 0.58874, 0.4947
# --- tanh result report ---
# train acc, test acc | 0.59366, 0.49
# --- tanh result report ---
# train acc, test acc | 0.5974, 0.4955
# --- tanh result report ---
# train acc, test acc | 0.57146, 0.4744
# --- tanh result report ---
# train acc, test acc | 0.59064, 0.4852
# --- tanh result report ---
# train acc, test acc | 0.58818, 0.4873
# --- tanh result report ---
# train acc, test acc | 0.60708, 0.4919
# --- tanh result report ---
# train acc, test acc | 0.60496, 0.4876
# --- tanh result report ---
# train acc, test acc | 0.58762, 0.4802
# --- tanh result report ---
# train acc, test acc | 0.58506, 0.4815
# --- tanh result report ---
# train acc, test acc | 0.61036, 0.492
# --- tanh result report ---
# train acc, test acc | 0.61044, 0.493
# --- tanh result report ---
# train acc, test acc | 0.59312, 0.4782
# --- tanh result report ---
# train acc, test acc | 0.61338, 0.487
# --- tanh result report ---
# train acc, test acc | 0.61802, 0.4972
# --- tanh result report ---
# train acc, test acc | 0.59588, 0.4809
# --- tanh result report ---
# train acc, test acc | 0.60508, 0.4857
# --- tanh result report ---
# train acc, test acc | 0.61946, 0.484
# --- tanh result report ---
# train acc, test acc | 0.62924, 0.4917
# --- tanh result report ---
# train acc, test acc | 0.60568, 0.4807
# --- tanh result report ---
# train acc, test acc | 0.59718, 0.4737
# --- tanh result report ---
# train acc, test acc | 0.60396, 0.476
# --- tanh result report ---
# train acc, test acc | 0.59804, 0.473
# --- tanh result report ---
# train acc, test acc | 0.6102, 0.4853
# --- tanh result report ---
# train acc, test acc | 0.61174, 0.481
# --- tanh result report ---
# train acc, test acc | 0.6286, 0.4833
# --- tanh result report ---
# train acc, test acc | 0.61988, 0.4822
# --- tanh result report ---
# train acc, test acc | 0.62728, 0.4872
# --- tanh result report ---
# train acc, test acc | 0.64196, 0.4867
# --- tanh result report ---
# train acc, test acc | 0.62092, 0.48
# --- tanh result report ---
# train acc, test acc | 0.63776, 0.4909
# --- tanh result report ---
# train acc, test acc | 0.6241, 0.4692
# --- tanh result report ---
# train acc, test acc | 0.6323, 0.4837
# --- tanh result report ---
# train acc, test acc | 0.62626, 0.4781
# --- tanh result report ---
# train acc, test acc | 0.65912, 0.4948
# --- tanh result report ---
# train acc, test acc | 0.62724, 0.4866
# --- tanh result report ---
# train acc, test acc | 0.65018, 0.4924
# --- tanh result report ---
# train acc, test acc | 0.61628, 0.4656
# --- tanh result report ---
# train acc, test acc | 0.6325, 0.4754
# --- tanh result report ---
# train acc, test acc | 0.6552, 0.4934
# --- tanh result report ---
# train acc, test acc | 0.64882, 0.4898
# --- tanh result report ---
# train acc, test acc | 0.63476, 0.4865
# --- tanh result report ---
# train acc, test acc | 0.61128, 0.4707
# --- tanh result report ---
# train acc, test acc | 0.64902, 0.4904
# --- tanh result report ---
# train acc, test acc | 0.6591, 0.4919
# --- tanh result report ---
# train acc, test acc | 0.64976, 0.4876
# --- tanh result report ---
# train acc, test acc | 0.66792, 0.4971
# --- tanh result report ---
# train acc, test acc | 0.63776, 0.4699
# --- tanh result report ---
# train acc, test acc | 0.62966, 0.4685
# --- tanh result report ---
# train acc, test acc | 0.63488, 0.4747
# --- tanh result report ---
# train acc, test acc | 0.63692, 0.4681
# --- tanh result report ---
# train acc, test acc | 0.62376, 0.4661
# --- tanh result report ---
# train acc, test acc | 0.64344, 0.4759
# --- tanh result report ---
# train acc, test acc | 0.64872, 0.4761
# --- tanh result report ---
# train acc, test acc | 0.66376, 0.4823
# ==========
#
#
#
# === relu network training start ===
# --- relu result report ---
# train acc, test acc | 0.1276, 0.1264
# --- relu result report ---
# train acc, test acc | 0.3392, 0.3444
# --- relu result report ---
# train acc, test acc | 0.39136, 0.3832
# --- relu result report ---
# train acc, test acc | 0.36782, 0.3652
# --- relu result report ---
# train acc, test acc | 0.38104, 0.3707
# --- relu result report ---
# train acc, test acc | 0.41476, 0.4084
# --- relu result report ---
# train acc, test acc | 0.43672, 0.4281
# --- relu result report ---
# train acc, test acc | 0.458, 0.4475
# --- relu result report ---
# train acc, test acc | 0.42476, 0.409
# --- relu result report ---
# train acc, test acc | 0.48062, 0.4638
# --- relu result report ---
# train acc, test acc | 0.47136, 0.4544
# --- relu result report ---
# train acc, test acc | 0.44646, 0.4347
# --- relu result report ---
# train acc, test acc | 0.48498, 0.4652
# --- relu result report ---
# train acc, test acc | 0.43756, 0.4187
# --- relu result report ---
# train acc, test acc | 0.47536, 0.4553
# --- relu result report ---
# train acc, test acc | 0.46864, 0.4475
# --- relu result report ---
# train acc, test acc | 0.48096, 0.4522
# --- relu result report ---
# train acc, test acc | 0.48546, 0.4583
# --- relu result report ---
# train acc, test acc | 0.48542, 0.4588
# --- relu result report ---
# train acc, test acc | 0.4819, 0.4516
# --- relu result report ---
# train acc, test acc | 0.5067, 0.4714
# --- relu result report ---
# train acc, test acc | 0.43418, 0.4068
# --- relu result report ---
# train acc, test acc | 0.5036, 0.4677
# --- relu result report ---
# train acc, test acc | 0.48358, 0.4428
# --- relu result report ---
# train acc, test acc | 0.50342, 0.4644
# --- relu result report ---
# train acc, test acc | 0.50016, 0.4574
# --- relu result report ---
# train acc, test acc | 0.51158, 0.4686
# --- relu result report ---
# train acc, test acc | 0.41776, 0.3876
# --- relu result report ---
# train acc, test acc | 0.4957, 0.4482
# --- relu result report ---
# train acc, test acc | 0.50576, 0.4591
# --- relu result report ---
# train acc, test acc | 0.52362, 0.4736
# --- relu result report ---
# train acc, test acc | 0.50022, 0.4559
# --- relu result report ---
# train acc, test acc | 0.53078, 0.4833
# --- relu result report ---
# train acc, test acc | 0.5226, 0.4696
# --- relu result report ---
# train acc, test acc | 0.50468, 0.452
# --- relu result report ---
# train acc, test acc | 0.51128, 0.4599
# --- relu result report ---
# train acc, test acc | 0.52212, 0.4612
# --- relu result report ---
# train acc, test acc | 0.51032, 0.4608
# --- relu result report ---
# train acc, test acc | 0.53346, 0.4792
# --- relu result report ---
# train acc, test acc | 0.52826, 0.47
# --- relu result report ---
# train acc, test acc | 0.54162, 0.4774
# --- relu result report ---
# train acc, test acc | 0.52576, 0.4646
# --- relu result report ---
# train acc, test acc | 0.5181, 0.4569
# --- relu result report ---
# train acc, test acc | 0.53562, 0.4729
# --- relu result report ---
# train acc, test acc | 0.53724, 0.478
# --- relu result report ---
# train acc, test acc | 0.55898, 0.4882
# --- relu result report ---
# train acc, test acc | 0.52264, 0.4695
# --- relu result report ---
# train acc, test acc | 0.52516, 0.4671
# --- relu result report ---
# train acc, test acc | 0.49564, 0.4438
# --- relu result report ---
# train acc, test acc | 0.53224, 0.4684
# --- relu result report ---
# train acc, test acc | 0.54426, 0.4736
# --- relu result report ---
# train acc, test acc | 0.5373, 0.4788
# --- relu result report ---
# train acc, test acc | 0.52094, 0.4542
# --- relu result report ---
# train acc, test acc | 0.53108, 0.4623
# --- relu result report ---
# train acc, test acc | 0.5498, 0.4789
# --- relu result report ---
# train acc, test acc | 0.55864, 0.486
# --- relu result report ---
# train acc, test acc | 0.56544, 0.4938
# --- relu result report ---
# train acc, test acc | 0.56098, 0.4888
# --- relu result report ---
# train acc, test acc | 0.54338, 0.4689
# --- relu result report ---
# train acc, test acc | 0.55384, 0.4783
# --- relu result report ---
# train acc, test acc | 0.56732, 0.4837
# --- relu result report ---
# train acc, test acc | 0.5578, 0.4818
# --- relu result report ---
# train acc, test acc | 0.54658, 0.4694
# --- relu result report ---
# train acc, test acc | 0.56758, 0.4784
# --- relu result report ---
# train acc, test acc | 0.5643, 0.4806
# --- relu result report ---
# train acc, test acc | 0.56836, 0.4779
# --- relu result report ---
# train acc, test acc | 0.5522, 0.4647
# --- relu result report ---
# train acc, test acc | 0.55376, 0.4721
# --- relu result report ---
# train acc, test acc | 0.55364, 0.4855
# --- relu result report ---
# train acc, test acc | 0.55176, 0.468
# --- relu result report ---
# train acc, test acc | 0.49734, 0.4291
# --- relu result report ---
# train acc, test acc | 0.5578, 0.4753
# --- relu result report ---
# train acc, test acc | 0.58064, 0.4822
# --- relu result report ---
# train acc, test acc | 0.5608, 0.4721
# --- relu result report ---
# train acc, test acc | 0.54624, 0.4675
# --- relu result report ---
# train acc, test acc | 0.57566, 0.488
# --- relu result report ---
# train acc, test acc | 0.5703, 0.4773
# --- relu result report ---
# train acc, test acc | 0.54412, 0.4651
# --- relu result report ---
# train acc, test acc | 0.57386, 0.482
# --- relu result report ---
# train acc, test acc | 0.53338, 0.4527
# --- relu result report ---
# train acc, test acc | 0.5725, 0.4795
# --- relu result report ---
# train acc, test acc | 0.58246, 0.4845
# --- relu result report ---
# train acc, test acc | 0.57056, 0.47
# --- relu result report ---
# train acc, test acc | 0.57118, 0.4697
# --- relu result report ---
# train acc, test acc | 0.56876, 0.4793
# --- relu result report ---
# train acc, test acc | 0.58104, 0.4812
# --- relu result report ---
# train acc, test acc | 0.58468, 0.489
# --- relu result report ---
# train acc, test acc | 0.56314, 0.466
# --- relu result report ---
# train acc, test acc | 0.58538, 0.4822
# --- relu result report ---
# train acc, test acc | 0.57376, 0.4733
# --- relu result report ---
# train acc, test acc | 0.56068, 0.4611
# --- relu result report ---
# train acc, test acc | 0.59952, 0.489
# --- relu result report ---
# train acc, test acc | 0.5436, 0.4514
# --- relu result report ---
# train acc, test acc | 0.56812, 0.4663
# --- relu result report ---
# train acc, test acc | 0.5871, 0.4751
# --- relu result report ---
# train acc, test acc | 0.54464, 0.4519
# --- relu result report ---
# train acc, test acc | 0.59168, 0.4805
# --- relu result report ---
# train acc, test acc | 0.57308, 0.4739
# --- relu result report ---
# train acc, test acc | 0.57876, 0.4702
# --- relu result report ---
# train acc, test acc | 0.56148, 0.4637
# ==========
#
#
#
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.10016, 0.1005
# --- leaky result report ---
# train acc, test acc | 0.3232, 0.3155
# --- leaky result report ---
# train acc, test acc | 0.39734, 0.3909
# --- leaky result report ---
# train acc, test acc | 0.4109, 0.4029
# --- leaky result report ---
# train acc, test acc | 0.42522, 0.4137
# --- leaky result report ---
# train acc, test acc | 0.45276, 0.4368
# --- leaky result report ---
# train acc, test acc | 0.45908, 0.4411
# --- leaky result report ---
# train acc, test acc | 0.45354, 0.4311
# --- leaky result report ---
# train acc, test acc | 0.47842, 0.4591
# --- leaky result report ---
# train acc, test acc | 0.45524, 0.4347
# --- leaky result report ---
# train acc, test acc | 0.478, 0.4496
# --- leaky result report ---
# train acc, test acc | 0.49578, 0.4695
# --- leaky result report ---
# train acc, test acc | 0.48814, 0.4534
# --- leaky result report ---
# train acc, test acc | 0.47554, 0.4453
# --- leaky result report ---
# train acc, test acc | 0.4943, 0.4588
# --- leaky result report ---
# train acc, test acc | 0.46248, 0.4288
# --- leaky result report ---
# train acc, test acc | 0.5207, 0.487
# --- leaky result report ---
# train acc, test acc | 0.52328, 0.4791
# --- leaky result report ---
# train acc, test acc | 0.50544, 0.466
# --- leaky result report ---
# train acc, test acc | 0.51468, 0.4672
# --- leaky result report ---
# train acc, test acc | 0.52376, 0.4823
# --- leaky result report ---
# train acc, test acc | 0.53802, 0.4842
# --- leaky result report ---
# train acc, test acc | 0.53124, 0.4785
# --- leaky result report ---
# train acc, test acc | 0.5157, 0.4665
# --- leaky result report ---
# train acc, test acc | 0.51752, 0.4632
# --- leaky result report ---
# train acc, test acc | 0.55168, 0.4924
# --- leaky result report ---
# train acc, test acc | 0.566, 0.5063
# --- leaky result report ---
# train acc, test acc | 0.51188, 0.4587
# --- leaky result report ---
# train acc, test acc | 0.55334, 0.4899
# --- leaky result report ---
# train acc, test acc | 0.54286, 0.4767
# --- leaky result report ---
# train acc, test acc | 0.55426, 0.4822
# --- leaky result report ---
# train acc, test acc | 0.53438, 0.4727
# --- leaky result report ---
# train acc, test acc | 0.56964, 0.4997
# --- leaky result report ---
# train acc, test acc | 0.58306, 0.5127
# --- leaky result report ---
# train acc, test acc | 0.58166, 0.5018
# --- leaky result report ---
# train acc, test acc | 0.57284, 0.498
# --- leaky result report ---
# train acc, test acc | 0.58656, 0.5063
# --- leaky result report ---
# train acc, test acc | 0.56478, 0.4843
# --- leaky result report ---
# train acc, test acc | 0.557, 0.4781
# --- leaky result report ---
# train acc, test acc | 0.5575, 0.4755
# --- leaky result report ---
# train acc, test acc | 0.57706, 0.4959
# --- leaky result report ---
# train acc, test acc | 0.57918, 0.4894
# --- leaky result report ---
# train acc, test acc | 0.5947, 0.4995
# --- leaky result report ---
# train acc, test acc | 0.53144, 0.4599
# --- leaky result report ---
# train acc, test acc | 0.57598, 0.4879
# --- leaky result report ---
# train acc, test acc | 0.5585, 0.4753
# --- leaky result report ---
# train acc, test acc | 0.58172, 0.4883
# --- leaky result report ---
# train acc, test acc | 0.58376, 0.4854
# --- leaky result report ---
# train acc, test acc | 0.60476, 0.5042
# --- leaky result report ---
# train acc, test acc | 0.54518, 0.4533
# --- leaky result report ---
# train acc, test acc | 0.53172, 0.4468
# --- leaky result report ---
# train acc, test acc | 0.5905, 0.4967
# --- leaky result report ---
# train acc, test acc | 0.60104, 0.4939
# --- leaky result report ---
# train acc, test acc | 0.57328, 0.477
# --- leaky result report ---
# train acc, test acc | 0.58796, 0.4807
# --- leaky result report ---
# train acc, test acc | 0.60116, 0.4882
# --- leaky result report ---
# train acc, test acc | 0.60982, 0.4909
# --- leaky result report ---
# train acc, test acc | 0.6099, 0.4904
# --- leaky result report ---
# train acc, test acc | 0.60522, 0.4921
# --- leaky result report ---
# train acc, test acc | 0.61842, 0.4893
# --- leaky result report ---
# train acc, test acc | 0.61894, 0.4969
# --- leaky result report ---
# train acc, test acc | 0.55432, 0.4606
# --- leaky result report ---
# train acc, test acc | 0.61986, 0.504
# --- leaky result report ---
# train acc, test acc | 0.61558, 0.4907
# --- leaky result report ---
# train acc, test acc | 0.60876, 0.4952
# --- leaky result report ---
# train acc, test acc | 0.63652, 0.5017
# --- leaky result report ---
# train acc, test acc | 0.58178, 0.4661
# --- leaky result report ---
# train acc, test acc | 0.6031, 0.4887
# --- leaky result report ---
# train acc, test acc | 0.6264, 0.4972
# --- leaky result report ---
# train acc, test acc | 0.59792, 0.486
# --- leaky result report ---
# train acc, test acc | 0.62444, 0.4981
# --- leaky result report ---
# train acc, test acc | 0.62896, 0.4971
# --- leaky result report ---
# train acc, test acc | 0.62924, 0.4977
# --- leaky result report ---
# train acc, test acc | 0.64432, 0.5061
# --- leaky result report ---
# train acc, test acc | 0.62146, 0.494
# --- leaky result report ---
# train acc, test acc | 0.5792, 0.4691
# --- leaky result report ---
# train acc, test acc | 0.60776, 0.483
# --- leaky result report ---
# train acc, test acc | 0.63232, 0.4874
# --- leaky result report ---
# train acc, test acc | 0.63122, 0.4914
# --- leaky result report ---
# train acc, test acc | 0.58254, 0.4682
# --- leaky result report ---
# train acc, test acc | 0.62528, 0.4902
# --- leaky result report ---
# train acc, test acc | 0.6009, 0.4721
# --- leaky result report ---
# train acc, test acc | 0.64524, 0.5053
# --- leaky result report ---
# train acc, test acc | 0.64626, 0.4909
# --- leaky result report ---
# train acc, test acc | 0.63356, 0.4883
# --- leaky result report ---
# train acc, test acc | 0.627, 0.4874
# --- leaky result report ---
# train acc, test acc | 0.64006, 0.4897
# --- leaky result report ---
# train acc, test acc | 0.62098, 0.4899
# --- leaky result report ---
# train acc, test acc | 0.63932, 0.4928
# --- leaky result report ---
# train acc, test acc | 0.64312, 0.4876
# --- leaky result report ---
# train acc, test acc | 0.62924, 0.4828
# --- leaky result report ---
# train acc, test acc | 0.63122, 0.4829
# --- leaky result report ---
# train acc, test acc | 0.64794, 0.494
# --- leaky result report ---
# train acc, test acc | 0.64534, 0.4944
# --- leaky result report ---
# train acc, test acc | 0.65586, 0.4934
# --- leaky result report ---
# train acc, test acc | 0.64796, 0.493
# --- leaky result report ---
# train acc, test acc | 0.62746, 0.4772
# --- leaky result report ---
# train acc, test acc | 0.6407, 0.4853
# --- leaky result report ---
# train acc, test acc | 0.6156, 0.4766
# --- leaky result report ---
# train acc, test acc | 0.65866, 0.4904
# ==========

# %%
for k, v in output_dict.items():
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
plt.ylim([0.0, 1.0])
plt.legend(loc='lower right', prop={'size':7})
plt.grid()
