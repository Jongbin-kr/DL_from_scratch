# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
test_dict = {}
train_dict = {}
root_path = '../datasets/cifar-10-batches-py/'


def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

accepted_keys = [b'labels', b'data'] ## select keys from [b'batch_label', b'labels', b'data', b'filenames']
for dir in os.listdir(root_path):
    if dir == 'batches.meta':
        pass
    elif dir == 'test_batch':
        test_batch = unpickle(os.path.join(root_path, dir))
        test_dict.update((k,np.array(v)) for k,v in test_batch.items() if k in accepted_keys)
    else:
        train_batch = unpickle(os.path.join(root_path, dir))
        if not train_dict:
            train_dict.update((k,np.array(v)) for k,v in train_batch.items() if k in accepted_keys)
        else:
            for key in accepted_keys:
                train_dict[key] = np.concatenate((train_dict[key], train_batch[key]), axis=0)


## CIFAR data's shape are (N, H*W*C). 
## If you want to convert them into numpy-standard (N, H, W, C) shape, run following codes.
def numpy2rgb(arr: np.ndarray) -> np.ndarray:
    batch_size = len(arr)
    arr = arr.reshape(batch_size, 3, 32, 32).transpose(0,2,3,1)
    
    return arr


train_dict[b'data'] = numpy2rgb(train_dict[b'data'])
test_dict[b'data'] = numpy2rgb(test_dict[b'data'])

# %%
def normalize(data: np.ndarray, mean: int=None, std: int=None) -> np.ndarray:
    if mean == None:
        mean = np.mean(data)
        
    if std == None:
        std = np.std(data)
    
    data = (data - mean) / std
    return data

# %%
x_train, t_train = normalize(train_dict[b'data']), train_dict[b'labels']
x_test, t_test = normalize(test_dict[b'data']), test_dict[b'labels']

print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 2.09341038199596
# (50000,)

# %%
network_dict = {
                'sigmoid-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='sigmoid', weight_init_std='he'),
                'tanh-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='tanh', weight_init_std='he'),
                'relu-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='relu', weight_init_std='he'),
                'leaky-he': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std='he'),
                }

# %%
# 하이퍼 파라메터
iters_num = 50_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === sigmoid-he network training start ===
# --- sigmoid-he result report ---
# train acc, test acc | 0.14382, 0.1448
# --- sigmoid-he result report ---
# train acc, test acc | 0.4161, 0.4103
# --- sigmoid-he result report ---
# train acc, test acc | 0.45334, 0.4344
# --- sigmoid-he result report ---
# train acc, test acc | 0.4735, 0.4441
# --- sigmoid-he result report ---
# train acc, test acc | 0.48452, 0.452
# --- sigmoid-he result report ---
# train acc, test acc | 0.49878, 0.4514
# --- sigmoid-he result report ---
# train acc, test acc | 0.51576, 0.4582
# --- sigmoid-he result report ---
# train acc, test acc | 0.51996, 0.4593
# --- sigmoid-he result report ---
# train acc, test acc | 0.5323, 0.458
# --- sigmoid-he result report ---
# train acc, test acc | 0.53726, 0.4578
# --- sigmoid-he result report ---
# train acc, test acc | 0.55166, 0.4612
# --- sigmoid-he result report ---
# train acc, test acc | 0.5575, 0.4622
# --- sigmoid-he result report ---
# train acc, test acc | 0.56998, 0.4608
# --- sigmoid-he result report ---
# train acc, test acc | 0.57602, 0.4674
# --- sigmoid-he result report ---
# train acc, test acc | 0.58102, 0.464
# --- sigmoid-he result report ---
# train acc, test acc | 0.59032, 0.4651
# --- sigmoid-he result report ---
# train acc, test acc | 0.59584, 0.4654
# --- sigmoid-he result report ---
# train acc, test acc | 0.60074, 0.4654
# --- sigmoid-he result report ---
# train acc, test acc | 0.60854, 0.4648
# --- sigmoid-he result report ---
# train acc, test acc | 0.60938, 0.4646
# --- sigmoid-he result report ---
# train acc, test acc | 0.61848, 0.4644
# --- sigmoid-he result report ---
# train acc, test acc | 0.61964, 0.4627
# --- sigmoid-he result report ---
# train acc, test acc | 0.619, 0.4597
# --- sigmoid-he result report ---
# train acc, test acc | 0.63236, 0.4547
# --- sigmoid-he result report ---
# train acc, test acc | 0.63792, 0.4595
# --- sigmoid-he result report ---
# train acc, test acc | 0.64002, 0.4589
# --- sigmoid-he result report ---
# train acc, test acc | 0.64788, 0.4578
# --- sigmoid-he result report ---
# train acc, test acc | 0.66158, 0.4556
# --- sigmoid-he result report ---
# train acc, test acc | 0.6617, 0.4576
# --- sigmoid-he result report ---
# train acc, test acc | 0.6613, 0.45
# --- sigmoid-he result report ---
# train acc, test acc | 0.66382, 0.4533
# --- sigmoid-he result report ---
# train acc, test acc | 0.6715, 0.4547
# --- sigmoid-he result report ---
# train acc, test acc | 0.68438, 0.455
# --- sigmoid-he result report ---
# train acc, test acc | 0.68264, 0.4529
# --- sigmoid-he result report ---
# train acc, test acc | 0.68972, 0.4602
# --- sigmoid-he result report ---
# train acc, test acc | 0.69408, 0.4518
# --- sigmoid-he result report ---
# train acc, test acc | 0.6975, 0.4543
# --- sigmoid-he result report ---
# train acc, test acc | 0.70022, 0.4556
# --- sigmoid-he result report ---
# train acc, test acc | 0.7006, 0.4495
# --- sigmoid-he result report ---
# train acc, test acc | 0.7112, 0.4547
# --- sigmoid-he result report ---
# train acc, test acc | 0.69776, 0.4416
# --- sigmoid-he result report ---
# train acc, test acc | 0.72474, 0.4469
# --- sigmoid-he result report ---
# train acc, test acc | 0.71894, 0.4424
# --- sigmoid-he result report ---
# train acc, test acc | 0.72366, 0.4448
# --- sigmoid-he result report ---
# train acc, test acc | 0.72948, 0.4473
# --- sigmoid-he result report ---
# train acc, test acc | 0.73242, 0.4446
# --- sigmoid-he result report ---
# train acc, test acc | 0.73266, 0.4425
# --- sigmoid-he result report ---
# train acc, test acc | 0.73932, 0.4442
# --- sigmoid-he result report ---
# train acc, test acc | 0.7477, 0.4458
# --- sigmoid-he result report ---
# train acc, test acc | 0.73852, 0.4405
# --- sigmoid-he result report ---
# train acc, test acc | 0.74918, 0.4444
# --- sigmoid-he result report ---
# train acc, test acc | 0.74386, 0.4469
# --- sigmoid-he result report ---
# train acc, test acc | 0.76108, 0.4421
# --- sigmoid-he result report ---
# train acc, test acc | 0.75166, 0.4431
# --- sigmoid-he result report ---
# train acc, test acc | 0.75508, 0.4453
# --- sigmoid-he result report ---
# train acc, test acc | 0.76376, 0.4428
# --- sigmoid-he result report ---
# train acc, test acc | 0.76792, 0.4422
# --- sigmoid-he result report ---
# train acc, test acc | 0.76896, 0.4395
# --- sigmoid-he result report ---
# train acc, test acc | 0.7716, 0.43
# --- sigmoid-he result report ---
# train acc, test acc | 0.77022, 0.4353
# --- sigmoid-he result report ---
# train acc, test acc | 0.7802, 0.4379
# --- sigmoid-he result report ---
# train acc, test acc | 0.77872, 0.4337
# --- sigmoid-he result report ---
# train acc, test acc | 0.7781, 0.4337
# --- sigmoid-he result report ---
# train acc, test acc | 0.78476, 0.4332
# --- sigmoid-he result report ---
# train acc, test acc | 0.7874, 0.4324
# --- sigmoid-he result report ---
# train acc, test acc | 0.7875, 0.4376
# --- sigmoid-he result report ---
# train acc, test acc | 0.7856, 0.4346
# --- sigmoid-he result report ---
# train acc, test acc | 0.79426, 0.4348
# --- sigmoid-he result report ---
# train acc, test acc | 0.78874, 0.4236
# --- sigmoid-he result report ---
# train acc, test acc | 0.79496, 0.4294
# --- sigmoid-he result report ---
# train acc, test acc | 0.80328, 0.4363
# --- sigmoid-he result report ---
# train acc, test acc | 0.81084, 0.4361
# --- sigmoid-he result report ---
# train acc, test acc | 0.80846, 0.4257
# --- sigmoid-he result report ---
# train acc, test acc | 0.80512, 0.4271
# --- sigmoid-he result report ---
# train acc, test acc | 0.81744, 0.4287
# --- sigmoid-he result report ---
# train acc, test acc | 0.807, 0.4261
# --- sigmoid-he result report ---
# train acc, test acc | 0.81532, 0.4335
# --- sigmoid-he result report ---
# train acc, test acc | 0.81994, 0.4246
# --- sigmoid-he result report ---
# train acc, test acc | 0.82248, 0.4305
# --- sigmoid-he result report ---
# train acc, test acc | 0.82152, 0.4322
# --- sigmoid-he result report ---
# train acc, test acc | 0.8099, 0.4312
# --- sigmoid-he result report ---
# train acc, test acc | 0.82742, 0.4312
# --- sigmoid-he result report ---
# train acc, test acc | 0.82698, 0.4304
# --- sigmoid-he result report ---
# train acc, test acc | 0.8273, 0.4267
# --- sigmoid-he result report ---
# train acc, test acc | 0.83986, 0.4282
# --- sigmoid-he result report ---
# train acc, test acc | 0.83216, 0.43
# --- sigmoid-he result report ---
# train acc, test acc | 0.83456, 0.4272
# --- sigmoid-he result report ---
# train acc, test acc | 0.8424, 0.4238
# --- sigmoid-he result report ---
# train acc, test acc | 0.83988, 0.4307
# --- sigmoid-he result report ---
# train acc, test acc | 0.84966, 0.4271
# --- sigmoid-he result report ---
# train acc, test acc | 0.83978, 0.4222
# --- sigmoid-he result report ---
# train acc, test acc | 0.83976, 0.42
# --- sigmoid-he result report ---
# train acc, test acc | 0.83638, 0.4176
# --- sigmoid-he result report ---
# train acc, test acc | 0.84266, 0.4229
# --- sigmoid-he result report ---
# train acc, test acc | 0.85108, 0.43
# --- sigmoid-he result report ---
# train acc, test acc | 0.8552, 0.4247
# --- sigmoid-he result report ---
# train acc, test acc | 0.8402, 0.4234
# --- sigmoid-he result report ---
# train acc, test acc | 0.86602, 0.4255
# --- sigmoid-he result report ---
# train acc, test acc | 0.86616, 0.4229
# --- sigmoid-he result report ---
# train acc, test acc | 0.86156, 0.4286
# ==========
#
#
#
# === tanh-he network training start ===
# --- tanh-he result report ---
# train acc, test acc | 0.15662, 0.1588
# --- tanh-he result report ---
# train acc, test acc | 0.4334, 0.4068
# --- tanh-he result report ---
# train acc, test acc | 0.44502, 0.4136
# --- tanh-he result report ---
# train acc, test acc | 0.4779, 0.4357
# --- tanh-he result report ---
# train acc, test acc | 0.4811, 0.4267
# --- tanh-he result report ---
# train acc, test acc | 0.5003, 0.4341
# --- tanh-he result report ---
# train acc, test acc | 0.50646, 0.4255
# --- tanh-he result report ---
# train acc, test acc | 0.52774, 0.4426
# --- tanh-he result report ---
# train acc, test acc | 0.5331, 0.4336
# --- tanh-he result report ---
# train acc, test acc | 0.54444, 0.4398
# --- tanh-he result report ---
# train acc, test acc | 0.54962, 0.4357
# --- tanh-he result report ---
# train acc, test acc | 0.55386, 0.4347
# --- tanh-he result report ---
# train acc, test acc | 0.5635, 0.4449
# --- tanh-he result report ---
# train acc, test acc | 0.56972, 0.4392
# --- tanh-he result report ---
# train acc, test acc | 0.57786, 0.439
# --- tanh-he result report ---
# train acc, test acc | 0.58772, 0.4396
# --- tanh-he result report ---
# train acc, test acc | 0.5932, 0.4437
# --- tanh-he result report ---
# train acc, test acc | 0.59966, 0.4432
# --- tanh-he result report ---
# train acc, test acc | 0.6018, 0.4344
# --- tanh-he result report ---
# train acc, test acc | 0.61416, 0.4374
# --- tanh-he result report ---
# train acc, test acc | 0.60236, 0.4372
# --- tanh-he result report ---
# train acc, test acc | 0.61944, 0.4452
# --- tanh-he result report ---
# train acc, test acc | 0.62034, 0.4385
# --- tanh-he result report ---
# train acc, test acc | 0.62748, 0.4432
# --- tanh-he result report ---
# train acc, test acc | 0.63938, 0.4381
# --- tanh-he result report ---
# train acc, test acc | 0.64026, 0.4444
# --- tanh-he result report ---
# train acc, test acc | 0.6478, 0.4403
# --- tanh-he result report ---
# train acc, test acc | 0.6409, 0.4328
# --- tanh-he result report ---
# train acc, test acc | 0.64988, 0.438
# --- tanh-he result report ---
# train acc, test acc | 0.65716, 0.432
# --- tanh-he result report ---
# train acc, test acc | 0.664, 0.432
# --- tanh-he result report ---
# train acc, test acc | 0.66432, 0.4312
# --- tanh-he result report ---
# train acc, test acc | 0.65872, 0.4262
# --- tanh-he result report ---
# train acc, test acc | 0.66412, 0.4305
# --- tanh-he result report ---
# train acc, test acc | 0.67092, 0.4309
# --- tanh-he result report ---
# train acc, test acc | 0.67174, 0.436
# --- tanh-he result report ---
# train acc, test acc | 0.6799, 0.4323
# --- tanh-he result report ---
# train acc, test acc | 0.6827, 0.4258
# --- tanh-he result report ---
# train acc, test acc | 0.692, 0.4297
# --- tanh-he result report ---
# train acc, test acc | 0.69616, 0.4244
# --- tanh-he result report ---
# train acc, test acc | 0.69482, 0.4279
# --- tanh-he result report ---
# train acc, test acc | 0.69694, 0.4312
# --- tanh-he result report ---
# train acc, test acc | 0.70656, 0.422
# --- tanh-he result report ---
# train acc, test acc | 0.70308, 0.4194
# --- tanh-he result report ---
# train acc, test acc | 0.7167, 0.4234
# --- tanh-he result report ---
# train acc, test acc | 0.71124, 0.4212
# --- tanh-he result report ---
# train acc, test acc | 0.70978, 0.4249
# --- tanh-he result report ---
# train acc, test acc | 0.71304, 0.4212
# --- tanh-he result report ---
# train acc, test acc | 0.71876, 0.4138
# --- tanh-he result report ---
# train acc, test acc | 0.71462, 0.416
# --- tanh-he result report ---
# train acc, test acc | 0.71486, 0.418
# --- tanh-he result report ---
# train acc, test acc | 0.72258, 0.4232
# --- tanh-he result report ---
# train acc, test acc | 0.72292, 0.4237
# --- tanh-he result report ---
# train acc, test acc | 0.73806, 0.4167
# --- tanh-he result report ---
# train acc, test acc | 0.7327, 0.4241
# --- tanh-he result report ---
# train acc, test acc | 0.73446, 0.4195
# --- tanh-he result report ---
# train acc, test acc | 0.74068, 0.41
# --- tanh-he result report ---
# train acc, test acc | 0.74562, 0.4249
# --- tanh-he result report ---
# train acc, test acc | 0.74178, 0.4136
# --- tanh-he result report ---
# train acc, test acc | 0.75538, 0.4161
# --- tanh-he result report ---
# train acc, test acc | 0.75986, 0.4184
# --- tanh-he result report ---
# train acc, test acc | 0.75284, 0.4138
# --- tanh-he result report ---
# train acc, test acc | 0.76048, 0.4181
# --- tanh-he result report ---
# train acc, test acc | 0.7631, 0.4069
# --- tanh-he result report ---
# train acc, test acc | 0.75508, 0.4096
# --- tanh-he result report ---
# train acc, test acc | 0.75966, 0.4184
# --- tanh-he result report ---
# train acc, test acc | 0.76608, 0.4097
# --- tanh-he result report ---
# train acc, test acc | 0.77, 0.4069
# --- tanh-he result report ---
# train acc, test acc | 0.7759, 0.4187
# --- tanh-he result report ---
# train acc, test acc | 0.76806, 0.413
# --- tanh-he result report ---
# train acc, test acc | 0.77244, 0.4139
# --- tanh-he result report ---
# train acc, test acc | 0.78386, 0.4165
# --- tanh-he result report ---
# train acc, test acc | 0.76924, 0.4165
# --- tanh-he result report ---
# train acc, test acc | 0.77756, 0.4071
# --- tanh-he result report ---
# train acc, test acc | 0.78424, 0.4151
# --- tanh-he result report ---
# train acc, test acc | 0.7846, 0.4128
# --- tanh-he result report ---
# train acc, test acc | 0.78342, 0.4131
# --- tanh-he result report ---
# train acc, test acc | 0.78958, 0.4164
# --- tanh-he result report ---
# train acc, test acc | 0.7809, 0.4155
# --- tanh-he result report ---
# train acc, test acc | 0.78722, 0.4115
# --- tanh-he result report ---
# train acc, test acc | 0.79342, 0.4158
# --- tanh-he result report ---
# train acc, test acc | 0.78628, 0.4091
# --- tanh-he result report ---
# train acc, test acc | 0.80442, 0.4148
# --- tanh-he result report ---
# train acc, test acc | 0.7957, 0.4069
# --- tanh-he result report ---
# train acc, test acc | 0.79444, 0.4103
# --- tanh-he result report ---
# train acc, test acc | 0.80156, 0.4113
# --- tanh-he result report ---
# train acc, test acc | 0.79786, 0.4145
# --- tanh-he result report ---
# train acc, test acc | 0.80544, 0.4075
# --- tanh-he result report ---
# train acc, test acc | 0.7962, 0.4088
# --- tanh-he result report ---
# train acc, test acc | 0.7934, 0.4044
# --- tanh-he result report ---
# train acc, test acc | 0.81718, 0.4136
# --- tanh-he result report ---
# train acc, test acc | 0.82034, 0.4074
# --- tanh-he result report ---
# train acc, test acc | 0.806, 0.4145
# --- tanh-he result report ---
# train acc, test acc | 0.81362, 0.4174
# --- tanh-he result report ---
# train acc, test acc | 0.80734, 0.4115
# --- tanh-he result report ---
# train acc, test acc | 0.80812, 0.4061
# --- tanh-he result report ---
# train acc, test acc | 0.81098, 0.4081
# --- tanh-he result report ---
# train acc, test acc | 0.81894, 0.4044
# --- tanh-he result report ---
# train acc, test acc | 0.82368, 0.4109
# --- tanh-he result report ---
# train acc, test acc | 0.81872, 0.4086
# ==========
#
#
#
# === relu-he network training start ===
# --- relu-he result report ---
# train acc, test acc | 0.18912, 0.1931
# --- relu-he result report ---
# train acc, test acc | 0.45622, 0.4346
# --- relu-he result report ---
# train acc, test acc | 0.49658, 0.4559
# --- relu-he result report ---
# train acc, test acc | 0.52582, 0.4726
# --- relu-he result report ---
# train acc, test acc | 0.49806, 0.4446
# --- relu-he result report ---
# train acc, test acc | 0.5174, 0.4554
# --- relu-he result report ---
# train acc, test acc | 0.55696, 0.4871
# --- relu-he result report ---
# train acc, test acc | 0.54876, 0.4664
# --- relu-he result report ---
# train acc, test acc | 0.55978, 0.4703
# --- relu-he result report ---
# train acc, test acc | 0.57546, 0.4655
# --- relu-he result report ---
# train acc, test acc | 0.56642, 0.478
# --- relu-he result report ---
# train acc, test acc | 0.55224, 0.4521
# --- relu-he result report ---
# train acc, test acc | 0.61006, 0.4936
# --- relu-he result report ---
# train acc, test acc | 0.6006, 0.4841
# --- relu-he result report ---
# train acc, test acc | 0.61442, 0.4787
# --- relu-he result report ---
# train acc, test acc | 0.62968, 0.488
# --- relu-he result report ---
# train acc, test acc | 0.60264, 0.4784
# --- relu-he result report ---
# train acc, test acc | 0.6398, 0.496
# --- relu-he result report ---
# train acc, test acc | 0.61128, 0.4649
# --- relu-he result report ---
# train acc, test acc | 0.64626, 0.4897
# --- relu-he result report ---
# train acc, test acc | 0.6461, 0.4827
# --- relu-he result report ---
# train acc, test acc | 0.66156, 0.4887
# --- relu-he result report ---
# train acc, test acc | 0.66092, 0.4782
# --- relu-he result report ---
# train acc, test acc | 0.66534, 0.4876
# --- relu-he result report ---
# train acc, test acc | 0.6353, 0.4697
# --- relu-he result report ---
# train acc, test acc | 0.6371, 0.4641
# --- relu-he result report ---
# train acc, test acc | 0.66734, 0.4772
# --- relu-he result report ---
# train acc, test acc | 0.6772, 0.4768
# --- relu-he result report ---
# train acc, test acc | 0.66018, 0.4614
# --- relu-he result report ---
# train acc, test acc | 0.67626, 0.4719
# --- relu-he result report ---
# train acc, test acc | 0.69176, 0.4831
# --- relu-he result report ---
# train acc, test acc | 0.69744, 0.4859
# --- relu-he result report ---
# train acc, test acc | 0.71486, 0.4886
# --- relu-he result report ---
# train acc, test acc | 0.71814, 0.4987
# --- relu-he result report ---
# train acc, test acc | 0.71712, 0.4897
# --- relu-he result report ---
# train acc, test acc | 0.70714, 0.4839
# --- relu-he result report ---
# train acc, test acc | 0.68394, 0.4751
# --- relu-he result report ---
# train acc, test acc | 0.6974, 0.4728
# --- relu-he result report ---
# train acc, test acc | 0.71826, 0.4823
# --- relu-he result report ---
# train acc, test acc | 0.72806, 0.4901
# --- relu-he result report ---
# train acc, test acc | 0.715, 0.4728
# --- relu-he result report ---
# train acc, test acc | 0.6769, 0.449
# --- relu-he result report ---
# train acc, test acc | 0.71784, 0.4752
# --- relu-he result report ---
# train acc, test acc | 0.72454, 0.4719
# --- relu-he result report ---
# train acc, test acc | 0.71942, 0.4713
# --- relu-he result report ---
# train acc, test acc | 0.72674, 0.4664
# --- relu-he result report ---
# train acc, test acc | 0.73746, 0.4712
# --- relu-he result report ---
# train acc, test acc | 0.75596, 0.4823
# --- relu-he result report ---
# train acc, test acc | 0.71728, 0.4727
# --- relu-he result report ---
# train acc, test acc | 0.76194, 0.4805
# --- relu-he result report ---
# train acc, test acc | 0.75202, 0.4771
# --- relu-he result report ---
# train acc, test acc | 0.73892, 0.4777
# --- relu-he result report ---
# train acc, test acc | 0.73762, 0.4703
# --- relu-he result report ---
# train acc, test acc | 0.7575, 0.4801
# --- relu-he result report ---
# train acc, test acc | 0.74002, 0.4768
# --- relu-he result report ---
# train acc, test acc | 0.7671, 0.4768
# --- relu-he result report ---
# train acc, test acc | 0.75886, 0.4815
# --- relu-he result report ---
# train acc, test acc | 0.77354, 0.4783
# --- relu-he result report ---
# train acc, test acc | 0.77224, 0.4808
# --- relu-he result report ---
# train acc, test acc | 0.77358, 0.4731
# --- relu-he result report ---
# train acc, test acc | 0.75912, 0.4742
# --- relu-he result report ---
# train acc, test acc | 0.77106, 0.4721
# --- relu-he result report ---
# train acc, test acc | 0.778, 0.4715
# --- relu-he result report ---
# train acc, test acc | 0.79336, 0.486
# --- relu-he result report ---
# train acc, test acc | 0.74638, 0.4589
# --- relu-he result report ---
# train acc, test acc | 0.79278, 0.4813
# --- relu-he result report ---
# train acc, test acc | 0.77326, 0.464
# --- relu-he result report ---
# train acc, test acc | 0.80576, 0.4807
# --- relu-he result report ---
# train acc, test acc | 0.7871, 0.4717
# --- relu-he result report ---
# train acc, test acc | 0.79292, 0.4758
# --- relu-he result report ---
# train acc, test acc | 0.79122, 0.4714
# --- relu-he result report ---
# train acc, test acc | 0.77366, 0.4608
# --- relu-he result report ---
# train acc, test acc | 0.77768, 0.4676
# --- relu-he result report ---
# train acc, test acc | 0.79536, 0.4745
# --- relu-he result report ---
# train acc, test acc | 0.80146, 0.4718
# --- relu-he result report ---
# train acc, test acc | 0.77236, 0.4652
# --- relu-he result report ---
# train acc, test acc | 0.792, 0.4591
# --- relu-he result report ---
# train acc, test acc | 0.77962, 0.4635
# --- relu-he result report ---
# train acc, test acc | 0.78712, 0.4697
# --- relu-he result report ---
# train acc, test acc | 0.8153, 0.4755
# --- relu-he result report ---
# train acc, test acc | 0.78838, 0.4575
# --- relu-he result report ---
# train acc, test acc | 0.8048, 0.4687
# --- relu-he result report ---
# train acc, test acc | 0.82136, 0.4772
# --- relu-he result report ---
# train acc, test acc | 0.77316, 0.4682
# --- relu-he result report ---
# train acc, test acc | 0.81476, 0.4766
# --- relu-he result report ---
# train acc, test acc | 0.79878, 0.4677
# --- relu-he result report ---
# train acc, test acc | 0.81232, 0.4731
# --- relu-he result report ---
# train acc, test acc | 0.82402, 0.4701
# --- relu-he result report ---
# train acc, test acc | 0.8183, 0.4724
# --- relu-he result report ---
# train acc, test acc | 0.83868, 0.477
# --- relu-he result report ---
# train acc, test acc | 0.82776, 0.4684
# --- relu-he result report ---
# train acc, test acc | 0.84144, 0.4758
# --- relu-he result report ---
# train acc, test acc | 0.84818, 0.4838
# --- relu-he result report ---
# train acc, test acc | 0.82894, 0.4717
# --- relu-he result report ---
# train acc, test acc | 0.8382, 0.4726
# --- relu-he result report ---
# train acc, test acc | 0.84304, 0.4687
# --- relu-he result report ---
# train acc, test acc | 0.8289, 0.4675
# --- relu-he result report ---
# train acc, test acc | 0.83346, 0.4711
# --- relu-he result report ---
# train acc, test acc | 0.83226, 0.4713
# --- relu-he result report ---
# train acc, test acc | 0.86078, 0.4684
# ==========
#
#
#
# === leaky-he network training start ===
# --- leaky-he result report ---
# train acc, test acc | 0.19104, 0.1921
# --- leaky-he result report ---
# train acc, test acc | 0.43468, 0.4162
# --- leaky-he result report ---
# train acc, test acc | 0.49096, 0.4569
# --- leaky-he result report ---
# train acc, test acc | 0.49224, 0.4451
# --- leaky-he result report ---
# train acc, test acc | 0.53854, 0.481
# --- leaky-he result report ---
# train acc, test acc | 0.54408, 0.4781
# --- leaky-he result report ---
# train acc, test acc | 0.54872, 0.4825
# --- leaky-he result report ---
# train acc, test acc | 0.56638, 0.4873
# --- leaky-he result report ---
# train acc, test acc | 0.58572, 0.4892
# --- leaky-he result report ---
# train acc, test acc | 0.5568, 0.4678
# --- leaky-he result report ---
# train acc, test acc | 0.60076, 0.4977
# --- leaky-he result report ---
# train acc, test acc | 0.6031, 0.4917
# --- leaky-he result report ---
# train acc, test acc | 0.56018, 0.4548
# --- leaky-he result report ---
# train acc, test acc | 0.59548, 0.4762
# --- leaky-he result report ---
# train acc, test acc | 0.62496, 0.4869
# --- leaky-he result report ---
# train acc, test acc | 0.5875, 0.4722
# --- leaky-he result report ---
# train acc, test acc | 0.62204, 0.4875
# --- leaky-he result report ---
# train acc, test acc | 0.63192, 0.4918
# --- leaky-he result report ---
# train acc, test acc | 0.63904, 0.4813
# --- leaky-he result report ---
# train acc, test acc | 0.64648, 0.4937
# --- leaky-he result report ---
# train acc, test acc | 0.65158, 0.4903
# --- leaky-he result report ---
# train acc, test acc | 0.64744, 0.4786
# --- leaky-he result report ---
# train acc, test acc | 0.5819, 0.4434
# --- leaky-he result report ---
# train acc, test acc | 0.6435, 0.4737
# --- leaky-he result report ---
# train acc, test acc | 0.66284, 0.4852
# --- leaky-he result report ---
# train acc, test acc | 0.66668, 0.4818
# --- leaky-he result report ---
# train acc, test acc | 0.67536, 0.4914
# --- leaky-he result report ---
# train acc, test acc | 0.65648, 0.4762
# --- leaky-he result report ---
# train acc, test acc | 0.67632, 0.4699
# --- leaky-he result report ---
# train acc, test acc | 0.69152, 0.4924
# --- leaky-he result report ---
# train acc, test acc | 0.67312, 0.4686
# --- leaky-he result report ---
# train acc, test acc | 0.68816, 0.4795
# --- leaky-he result report ---
# train acc, test acc | 0.70332, 0.4844
# --- leaky-he result report ---
# train acc, test acc | 0.70664, 0.4866
# --- leaky-he result report ---
# train acc, test acc | 0.68454, 0.4716
# --- leaky-he result report ---
# train acc, test acc | 0.72198, 0.4895
# --- leaky-he result report ---
# train acc, test acc | 0.70234, 0.4818
# --- leaky-he result report ---
# train acc, test acc | 0.70222, 0.487
# --- leaky-he result report ---
# train acc, test acc | 0.67662, 0.4679
# --- leaky-he result report ---
# train acc, test acc | 0.72346, 0.4874
# --- leaky-he result report ---
# train acc, test acc | 0.69698, 0.4799
# --- leaky-he result report ---
# train acc, test acc | 0.72364, 0.4848
# --- leaky-he result report ---
# train acc, test acc | 0.6987, 0.4726
# --- leaky-he result report ---
# train acc, test acc | 0.7045, 0.4692
# --- leaky-he result report ---
# train acc, test acc | 0.72106, 0.4706
# --- leaky-he result report ---
# train acc, test acc | 0.74432, 0.4849
# --- leaky-he result report ---
# train acc, test acc | 0.74636, 0.4844
# --- leaky-he result report ---
# train acc, test acc | 0.75138, 0.4831
# --- leaky-he result report ---
# train acc, test acc | 0.75566, 0.4964
# --- leaky-he result report ---
# train acc, test acc | 0.74, 0.4646
# --- leaky-he result report ---
# train acc, test acc | 0.73894, 0.4732
# --- leaky-he result report ---
# train acc, test acc | 0.75314, 0.4739
# --- leaky-he result report ---
# train acc, test acc | 0.72686, 0.4715
# --- leaky-he result report ---
# train acc, test acc | 0.73784, 0.4656
# --- leaky-he result report ---
# train acc, test acc | 0.7577, 0.4674
# --- leaky-he result report ---
# train acc, test acc | 0.75084, 0.4789
# --- leaky-he result report ---
# train acc, test acc | 0.7359, 0.4684
# --- leaky-he result report ---
# train acc, test acc | 0.76216, 0.4776
# --- leaky-he result report ---
# train acc, test acc | 0.77442, 0.4785
# --- leaky-he result report ---
# train acc, test acc | 0.76656, 0.4804
# --- leaky-he result report ---
# train acc, test acc | 0.7862, 0.4818
# --- leaky-he result report ---
# train acc, test acc | 0.7706, 0.4788
# --- leaky-he result report ---
# train acc, test acc | 0.75724, 0.4671
# --- leaky-he result report ---
# train acc, test acc | 0.73518, 0.4538
# --- leaky-he result report ---
# train acc, test acc | 0.7927, 0.4807
# --- leaky-he result report ---
# train acc, test acc | 0.7616, 0.4703
# --- leaky-he result report ---
# train acc, test acc | 0.7906, 0.4734
# --- leaky-he result report ---
# train acc, test acc | 0.78108, 0.4689
# --- leaky-he result report ---
# train acc, test acc | 0.79848, 0.4734
# --- leaky-he result report ---
# train acc, test acc | 0.79826, 0.4852
# --- leaky-he result report ---
# train acc, test acc | 0.80262, 0.4734
# --- leaky-he result report ---
# train acc, test acc | 0.7875, 0.4598
# --- leaky-he result report ---
# train acc, test acc | 0.79894, 0.4719
# --- leaky-he result report ---
# train acc, test acc | 0.78338, 0.4692
# --- leaky-he result report ---
# train acc, test acc | 0.8001, 0.4763
# --- leaky-he result report ---
# train acc, test acc | 0.81, 0.4763
# --- leaky-he result report ---
# train acc, test acc | 0.80242, 0.4627
# --- leaky-he result report ---
# train acc, test acc | 0.80652, 0.4797
# --- leaky-he result report ---
# train acc, test acc | 0.81414, 0.4708
# --- leaky-he result report ---
# train acc, test acc | 0.81456, 0.4719
# --- leaky-he result report ---
# train acc, test acc | 0.8107, 0.4753
# --- leaky-he result report ---
# train acc, test acc | 0.80356, 0.4733
# --- leaky-he result report ---
# train acc, test acc | 0.81784, 0.4706
# --- leaky-he result report ---
# train acc, test acc | 0.82534, 0.4733
# --- leaky-he result report ---
# train acc, test acc | 0.8115, 0.4661
# --- leaky-he result report ---
# train acc, test acc | 0.81276, 0.4719
# --- leaky-he result report ---
# train acc, test acc | 0.82484, 0.4702
# --- leaky-he result report ---
# train acc, test acc | 0.81344, 0.4727
# --- leaky-he result report ---
# train acc, test acc | 0.78876, 0.4493
# --- leaky-he result report ---
# train acc, test acc | 0.84682, 0.4795
# --- leaky-he result report ---
# train acc, test acc | 0.8082, 0.4645
# --- leaky-he result report ---
# train acc, test acc | 0.82386, 0.4665
# --- leaky-he result report ---
# train acc, test acc | 0.81226, 0.4695
# --- leaky-he result report ---
# train acc, test acc | 0.83102, 0.4764
# --- leaky-he result report ---
# train acc, test acc | 0.81422, 0.4689
# --- leaky-he result report ---
# train acc, test acc | 0.8332, 0.4718
# --- leaky-he result report ---
# train acc, test acc | 0.82212, 0.4648
# --- leaky-he result report ---
# train acc, test acc | 0.82642, 0.4745
# --- leaky-he result report ---
# train acc, test acc | 0.83164, 0.4723
# --- leaky-he result report ---
# train acc, test acc | 0.84892, 0.4729
# ==========

# %%
for k, v in output_dict.items():
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
plt.ylim([0.0, 1.0])
plt.legend(loc='lower right', prop={'size':7})
plt.grid()
