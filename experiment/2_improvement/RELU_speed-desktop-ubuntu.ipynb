# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
test_dict = {}
train_dict = {}
root_path = '../how_deep_is_your_thought/cifar-10-batches-py/'


def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

accepted_keys = [b'labels', b'data'] ## select keys from [b'batch_label', b'labels', b'data', b'filenames']
for dir in os.listdir(root_path):
    if dir == 'batches.meta':
        pass
    elif dir == 'test_batch':
        test_batch = unpickle(os.path.join(root_path, dir))
        test_dict.update((k,np.array(v)) for k,v in test_batch.items() if k in accepted_keys)
    else:
        train_batch = unpickle(os.path.join(root_path, dir))
        if not train_dict:
            train_dict.update((k,np.array(v)) for k,v in train_batch.items() if k in accepted_keys)
        else:
            for key in accepted_keys:
                train_dict[key] = np.concatenate((train_dict[key], train_batch[key]), axis=0)


## CIFAR data's shape are (N, H*W*C). 
## If you want to convert them into numpy-standard (N, H, W, C) shape, run following codes.
def numpy2rgb(arr: np.ndarray) -> np.ndarray:
    batch_size = len(arr)
    arr = arr.reshape(batch_size, 3, 32, 32).transpose(0,2,3,1)
    
    return arr


train_dict[b'data'] = numpy2rgb(train_dict[b'data'])
test_dict[b'data'] = numpy2rgb(test_dict[b'data'])

# %%
x_train, t_train = train_dict[b'data'] / 255.0, train_dict[b'labels']
x_test, t_test = test_dict[b'data'] / 255.0, test_dict[b'labels']

print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (50000, 32, 32, 3)
# 1.0
# (50000,)

# %%
network_dict = {
                # 'relu': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[50], output_size=10, activation='relu', weight_init_std=0.01),
                # 'my_relu': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[50], output_size=10, activation='custom_relu', weight_init_std=0.01),
                'leaky': MultiLayerNetExtend(input_size=3*32*32, hidden_size_list=[50], output_size=10, activation='leaky', weight_init_std=0.01),
                }

# %%
# 하이퍼 파라메터
iters_num = 50_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
import time

output_dict = {}

for key, network in network_dict.items():
    start_time = time.time()

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
    
    running_time = time.time() - start_time
    print(f'running time is {running_time}')
    output_dict[f'{key} running time'] = running_time
    print('='*10)
    print('\n\n')
# Out:
# === relu network training start ===
# --- relu result report ---
# train acc, test acc | 0.3798, 0.3852
# --- relu result report ---
# train acc, test acc | 0.36824, 0.3668
# --- relu result report ---
# train acc, test acc | 0.42956, 0.4256
# --- relu result report ---
# train acc, test acc | 0.42186, 0.4174
# --- relu result report ---
# train acc, test acc | 0.43634, 0.4186
# --- relu result report ---
# train acc, test acc | 0.45716, 0.4428
# --- relu result report ---
# train acc, test acc | 0.41604, 0.4045
# --- relu result report ---
# train acc, test acc | 0.481, 0.4664
# --- relu result report ---
# train acc, test acc | 0.4258, 0.407
# --- relu result report ---
# train acc, test acc | 0.44236, 0.4265
# --- relu result report ---
# train acc, test acc | 0.47258, 0.4517
# --- relu result report ---
# train acc, test acc | 0.48406, 0.4566
# --- relu result report ---
# train acc, test acc | 0.48888, 0.4622
# --- relu result report ---
# train acc, test acc | 0.5019, 0.4739
# --- relu result report ---
# train acc, test acc | 0.499, 0.4715
# --- relu result report ---
# train acc, test acc | 0.48272, 0.464
# --- relu result report ---
# train acc, test acc | 0.49212, 0.4681
# --- relu result report ---
# train acc, test acc | 0.46478, 0.4357
# --- relu result report ---
# train acc, test acc | 0.52446, 0.4833
# --- relu result report ---
# train acc, test acc | 0.50344, 0.4656
# --- relu result report ---
# train acc, test acc | 0.48094, 0.4545
# --- relu result report ---
# train acc, test acc | 0.51538, 0.48
# --- relu result report ---
# train acc, test acc | 0.5206, 0.4819
# --- relu result report ---
# train acc, test acc | 0.53422, 0.4885
# --- relu result report ---
# train acc, test acc | 0.50872, 0.4637
# --- relu result report ---
# train acc, test acc | 0.48792, 0.4462
# --- relu result report ---
# train acc, test acc | 0.52422, 0.4792
# --- relu result report ---
# train acc, test acc | 0.51338, 0.4658
# --- relu result report ---
# train acc, test acc | 0.51686, 0.4716
# --- relu result report ---
# train acc, test acc | 0.51586, 0.4742
# --- relu result report ---
# train acc, test acc | 0.4961, 0.443
# --- relu result report ---
# train acc, test acc | 0.51728, 0.4654
# --- relu result report ---
# train acc, test acc | 0.51102, 0.4645
# --- relu result report ---
# train acc, test acc | 0.53662, 0.4877
# --- relu result report ---
# train acc, test acc | 0.5215, 0.4661
# --- relu result report ---
# train acc, test acc | 0.53686, 0.4834
# --- relu result report ---
# train acc, test acc | 0.54342, 0.4865
# --- relu result report ---
# train acc, test acc | 0.54192, 0.4803
# --- relu result report ---
# train acc, test acc | 0.5279, 0.4658
# --- relu result report ---
# train acc, test acc | 0.5342, 0.4794
# --- relu result report ---
# train acc, test acc | 0.49474, 0.4343
# --- relu result report ---
# train acc, test acc | 0.51518, 0.4546
# --- relu result report ---
# train acc, test acc | 0.55922, 0.4892
# --- relu result report ---
# train acc, test acc | 0.52724, 0.4569
# --- relu result report ---
# train acc, test acc | 0.5272, 0.4733
# --- relu result report ---
# train acc, test acc | 0.55824, 0.4874
# --- relu result report ---
# train acc, test acc | 0.53522, 0.4693
# --- relu result report ---
# train acc, test acc | 0.55738, 0.4836
# --- relu result report ---
# train acc, test acc | 0.53902, 0.465
# --- relu result report ---
# train acc, test acc | 0.56496, 0.489
# --- relu result report ---
# train acc, test acc | 0.55834, 0.4857
# --- relu result report ---
# train acc, test acc | 0.5526, 0.4774
# --- relu result report ---
# train acc, test acc | 0.53446, 0.477
# --- relu result report ---
# train acc, test acc | 0.5706, 0.4873
# --- relu result report ---
# train acc, test acc | 0.57354, 0.4937
# --- relu result report ---
# train acc, test acc | 0.56502, 0.4877
# --- relu result report ---
# train acc, test acc | 0.56954, 0.4915
# --- relu result report ---
# train acc, test acc | 0.55266, 0.4694
# --- relu result report ---
# train acc, test acc | 0.57788, 0.4934
# --- relu result report ---
# train acc, test acc | 0.56654, 0.4816
# --- relu result report ---
# train acc, test acc | 0.55616, 0.4821
# --- relu result report ---
# train acc, test acc | 0.5743, 0.4826
# --- relu result report ---
# train acc, test acc | 0.57654, 0.4896
# --- relu result report ---
# train acc, test acc | 0.57324, 0.4869
# --- relu result report ---
# train acc, test acc | 0.55834, 0.4738
# --- relu result report ---
# train acc, test acc | 0.55902, 0.4677
# --- relu result report ---
# train acc, test acc | 0.55892, 0.4675
# --- relu result report ---
# train acc, test acc | 0.5582, 0.4778
# --- relu result report ---
# train acc, test acc | 0.57842, 0.4834
# --- relu result report ---
# train acc, test acc | 0.57144, 0.4858
# --- relu result report ---
# train acc, test acc | 0.58662, 0.488
# --- relu result report ---
# train acc, test acc | 0.57614, 0.4891
# --- relu result report ---
# train acc, test acc | 0.5715, 0.4752
# --- relu result report ---
# train acc, test acc | 0.57892, 0.4849
# --- relu result report ---
# train acc, test acc | 0.58764, 0.4919
# --- relu result report ---
# train acc, test acc | 0.58514, 0.4848
# --- relu result report ---
# train acc, test acc | 0.5804, 0.4859
# --- relu result report ---
# train acc, test acc | 0.5902, 0.4927
# --- relu result report ---
# train acc, test acc | 0.55414, 0.4651
# --- relu result report ---
# train acc, test acc | 0.56904, 0.4755
# --- relu result report ---
# train acc, test acc | 0.55056, 0.4613
# --- relu result report ---
# train acc, test acc | 0.58434, 0.485
# --- relu result report ---
# train acc, test acc | 0.58082, 0.4843
# --- relu result report ---
# train acc, test acc | 0.56606, 0.4759
# --- relu result report ---
# train acc, test acc | 0.58372, 0.4818
# --- relu result report ---
# train acc, test acc | 0.57334, 0.48
# --- relu result report ---
# train acc, test acc | 0.57502, 0.4808
# --- relu result report ---
# train acc, test acc | 0.57264, 0.4771
# --- relu result report ---
# train acc, test acc | 0.57872, 0.4824
# --- relu result report ---
# train acc, test acc | 0.6042, 0.4857
# --- relu result report ---
# train acc, test acc | 0.57822, 0.4684
# --- relu result report ---
# train acc, test acc | 0.58918, 0.4864
# --- relu result report ---
# train acc, test acc | 0.58802, 0.476
# --- relu result report ---
# train acc, test acc | 0.5959, 0.4835
# --- relu result report ---
# train acc, test acc | 0.5827, 0.4757
# --- relu result report ---
# train acc, test acc | 0.61042, 0.4948
# --- relu result report ---
# train acc, test acc | 0.58872, 0.4776
# --- relu result report ---
# train acc, test acc | 0.57372, 0.4685
# --- relu result report ---
# train acc, test acc | 0.55636, 0.4675
# --- relu result report ---
# train acc, test acc | 0.58126, 0.4765
# running time is 408.89403462409973
# ==========
#
#
#
# === my_relu network training start ===
# --- my_relu result report ---
# train acc, test acc | 0.08758, 0.0873
# --- my_relu result report ---
# train acc, test acc | 0.27744, 0.2788
# --- my_relu result report ---
# train acc, test acc | 0.26396, 0.2615
# --- my_relu result report ---
# train acc, test acc | 0.26098, 0.2577
# --- my_relu result report ---
# train acc, test acc | 0.26244, 0.259
# --- my_relu result report ---
# train acc, test acc | 0.24172, 0.239
# --- my_relu result report ---
# train acc, test acc | 0.2252, 0.2242
# --- my_relu result report ---
# train acc, test acc | 0.23286, 0.234
# --- my_relu result report ---
# train acc, test acc | 0.19232, 0.1923
# --- my_relu result report ---
# train acc, test acc | 0.17096, 0.1712
# --- my_relu result report ---
# train acc, test acc | 0.17114, 0.1705
# --- my_relu result report ---
# train acc, test acc | 0.17198, 0.1694
# --- my_relu result report ---
# train acc, test acc | 0.1811, 0.1817
# --- my_relu result report ---
# train acc, test acc | 0.17838, 0.1804
# --- my_relu result report ---
# train acc, test acc | 0.18604, 0.1845
# --- my_relu result report ---
# train acc, test acc | 0.17158, 0.1704
# --- my_relu result report ---
# train acc, test acc | 0.16254, 0.158
# --- my_relu result report ---
# train acc, test acc | 0.136, 0.1387
# --- my_relu result report ---
# train acc, test acc | 0.13308, 0.1312
# --- my_relu result report ---
# train acc, test acc | 0.13656, 0.1356
# --- my_relu result report ---
# train acc, test acc | 0.1295, 0.1297
# --- my_relu result report ---
# train acc, test acc | 0.11814, 0.1175
# --- my_relu result report ---
# train acc, test acc | 0.1224, 0.123
# --- my_relu result report ---
# train acc, test acc | 0.1214, 0.1202
# --- my_relu result report ---
# train acc, test acc | 0.11788, 0.1187
# --- my_relu result report ---
# train acc, test acc | 0.11366, 0.1138
# --- my_relu result report ---
# train acc, test acc | 0.11978, 0.1192
# --- my_relu result report ---
# train acc, test acc | 0.12334, 0.1211
# --- my_relu result report ---
# train acc, test acc | 0.11336, 0.112
# --- my_relu result report ---
# train acc, test acc | 0.11774, 0.1172
# --- my_relu result report ---
# train acc, test acc | 0.10716, 0.1068
# --- my_relu result report ---
# train acc, test acc | 0.1078, 0.1084
# --- my_relu result report ---
# train acc, test acc | 0.10346, 0.1038
# --- my_relu result report ---
# train acc, test acc | 0.11038, 0.1105
# --- my_relu result report ---
# train acc, test acc | 0.10734, 0.1073
# --- my_relu result report ---
# train acc, test acc | 0.10376, 0.1042
# --- my_relu result report ---
# train acc, test acc | 0.10994, 0.1099
# --- my_relu result report ---
# train acc, test acc | 0.10508, 0.1058
# --- my_relu result report ---
# train acc, test acc | 0.10618, 0.1064
# --- my_relu result report ---
# train acc, test acc | 0.1073, 0.107
# --- my_relu result report ---
# train acc, test acc | 0.1041, 0.105
# --- my_relu result report ---
# train acc, test acc | 0.10058, 0.0995
# --- my_relu result report ---
# train acc, test acc | 0.10516, 0.1067
# --- my_relu result report ---
# train acc, test acc | 0.11126, 0.1109
# --- my_relu result report ---
# train acc, test acc | 0.10442, 0.1057
# --- my_relu result report ---
# train acc, test acc | 0.10992, 0.1091
# --- my_relu result report ---
# train acc, test acc | 0.11036, 0.1101
# --- my_relu result report ---
# train acc, test acc | 0.1001, 0.0994
# --- my_relu result report ---
# train acc, test acc | 0.1036, 0.1045
# --- my_relu result report ---
# train acc, test acc | 0.10098, 0.1005
# --- my_relu result report ---
# train acc, test acc | 0.10684, 0.1057
# --- my_relu result report ---
# train acc, test acc | 0.10674, 0.1058
# --- my_relu result report ---
# train acc, test acc | 0.10558, 0.1051
# --- my_relu result report ---
# train acc, test acc | 0.1115, 0.1112
# /home/jongbin/OneDrive_korea/2_My-Programming/0_DL_from_scratch/experiment/2_improvement/../../official_github/common/functions.py:56: RuntimeWarning: divide by zero encountered in log
#   return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size
# --- my_relu result report ---
# train acc, test acc | 0.10006, 0.0994
# --- my_relu result report ---
# train acc, test acc | 0.10452, 0.1048
# --- my_relu result report ---
# train acc, test acc | 0.10492, 0.1063
# --- my_relu result report ---
# train acc, test acc | 0.1008, 0.1004
# --- my_relu result report ---
# train acc, test acc | 0.1039, 0.1046
# --- my_relu result report ---
# train acc, test acc | 0.10828, 0.1085
# --- my_relu result report ---
# train acc, test acc | 0.09976, 0.0991
# --- my_relu result report ---
# train acc, test acc | 0.1107, 0.1101
# --- my_relu result report ---
# train acc, test acc | 0.1057, 0.1047
# --- my_relu result report ---
# train acc, test acc | 0.1017, 0.1025
# --- my_relu result report ---
# train acc, test acc | 0.1004, 0.1014
# --- my_relu result report ---
# train acc, test acc | 0.10846, 0.1084
# --- my_relu result report ---
# train acc, test acc | 0.1087, 0.1086
# --- my_relu result report ---
# train acc, test acc | 0.1064, 0.1057
# --- my_relu result report ---
# train acc, test acc | 0.10372, 0.1044
# --- my_relu result report ---
# train acc, test acc | 0.10214, 0.102
# --- my_relu result report ---
# train acc, test acc | 0.10548, 0.1039
# --- my_relu result report ---
# train acc, test acc | 0.10676, 0.1059
# --- my_relu result report ---
# train acc, test acc | 0.10332, 0.102
# --- my_relu result report ---
# train acc, test acc | 0.10132, 0.0998
# --- my_relu result report ---
# train acc, test acc | 0.10982, 0.1092
# --- my_relu result report ---
# train acc, test acc | 0.11124, 0.1103
# --- my_relu result report ---
# train acc, test acc | 0.1008, 0.0987
# --- my_relu result report ---
# train acc, test acc | 0.10346, 0.1036
# --- my_relu result report ---
# train acc, test acc | 0.10898, 0.1075
# --- my_relu result report ---
# train acc, test acc | 0.10456, 0.1054
# --- my_relu result report ---
# train acc, test acc | 0.10598, 0.1058
# --- my_relu result report ---
# train acc, test acc | 0.1042, 0.1043
# --- my_relu result report ---
# train acc, test acc | 0.10854, 0.1083
# --- my_relu result report ---
# train acc, test acc | 0.11084, 0.1104
# --- my_relu result report ---
# train acc, test acc | 0.10332, 0.1042
# --- my_relu result report ---
# train acc, test acc | 0.10336, 0.1037
# --- my_relu result report ---
# train acc, test acc | 0.10164, 0.1015
# --- my_relu result report ---
# train acc, test acc | 0.10322, 0.1038
# --- my_relu result report ---
# train acc, test acc | 0.1085, 0.1083
# --- my_relu result report ---
# train acc, test acc | 0.10784, 0.1078
# --- my_relu result report ---
# train acc, test acc | 0.10442, 0.1045
# --- my_relu result report ---
# train acc, test acc | 0.10348, 0.1039
# --- my_relu result report ---
# train acc, test acc | 0.10942, 0.1092
# --- my_relu result report ---
# train acc, test acc | 0.10236, 0.1029
# --- my_relu result report ---
# train acc, test acc | 0.10506, 0.1049
# --- my_relu result report ---
# train acc, test acc | 0.10674, 0.1074
# --- my_relu result report ---
# train acc, test acc | 0.10222, 0.1025
# --- my_relu result report ---
# train acc, test acc | 0.10556, 0.1049
# --- my_relu result report ---
# train acc, test acc | 0.10706, 0.1065
# --- my_relu result report ---
# train acc, test acc | 0.10932, 0.1086
# running time is 435.3088960647583
# ==========

# %%
for k, v in output_dict.items():
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        
plt.ylim([0.0, 1.0])
plt.legend(loc='lower right', prop={'size':7})
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 for k, v in output_dict.items():
# ----> 3     x = range(len(v))
#       5     if k.startswith('step'):
#       6         color_code = 'y'
#
# TypeError: object of type 'float' has no len()

# %%
import time

output_dict = {}

for key, network in network_dict.items():
    start_time = time.time()

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
    
    running_time = time.time() - start_time
    print(f'running time is {running_time}')
    output_dict[f'{key} running time'] = running_time
    print('='*10)
    print('\n\n')
# Out:
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.09908, 0.0959
# --- leaky result report ---
# train acc, test acc | 0.28352, 0.2869
# --- leaky result report ---
# train acc, test acc | 0.37552, 0.3729
# --- leaky result report ---
# train acc, test acc | 0.41024, 0.4016
# --- leaky result report ---
# train acc, test acc | 0.43452, 0.4278
# --- leaky result report ---
# train acc, test acc | 0.37676, 0.3761
# --- leaky result report ---
# train acc, test acc | 0.41978, 0.4158
# --- leaky result report ---
# train acc, test acc | 0.45884, 0.4441
# --- leaky result report ---
# train acc, test acc | 0.46326, 0.4542
# --- leaky result report ---
# train acc, test acc | 0.45914, 0.4444
# --- leaky result report ---
# train acc, test acc | 0.46372, 0.4471
# --- leaky result report ---
# train acc, test acc | 0.46862, 0.4465
# --- leaky result report ---
# train acc, test acc | 0.4533, 0.4317
# --- leaky result report ---
# train acc, test acc | 0.42096, 0.3978
# --- leaky result report ---
# train acc, test acc | 0.45892, 0.4367
# --- leaky result report ---
# train acc, test acc | 0.49328, 0.4593
# --- leaky result report ---
# train acc, test acc | 0.4753, 0.4481
# --- leaky result report ---
# train acc, test acc | 0.47786, 0.4476
# --- leaky result report ---
# train acc, test acc | 0.50982, 0.4694
# --- leaky result report ---
# train acc, test acc | 0.49832, 0.4654
# --- leaky result report ---
# train acc, test acc | 0.507, 0.468
# --- leaky result report ---
# train acc, test acc | 0.50372, 0.4736
# --- leaky result report ---
# train acc, test acc | 0.49418, 0.4575
# --- leaky result report ---
# train acc, test acc | 0.5175, 0.4737
# --- leaky result report ---
# train acc, test acc | 0.49496, 0.4586
# --- leaky result report ---
# train acc, test acc | 0.47938, 0.4447
# --- leaky result report ---
# train acc, test acc | 0.50502, 0.4663
# --- leaky result report ---
# train acc, test acc | 0.5137, 0.4695
# --- leaky result report ---
# train acc, test acc | 0.51648, 0.4663
# --- leaky result report ---
# train acc, test acc | 0.53142, 0.4815
# --- leaky result report ---
# train acc, test acc | 0.52802, 0.4836
# --- leaky result report ---
# train acc, test acc | 0.50846, 0.465
# --- leaky result report ---
# train acc, test acc | 0.5275, 0.4773
# --- leaky result report ---
# train acc, test acc | 0.53726, 0.4896
# --- leaky result report ---
# train acc, test acc | 0.48376, 0.435
# --- leaky result report ---
# train acc, test acc | 0.54082, 0.4795
# --- leaky result report ---
# train acc, test acc | 0.51344, 0.4703
# --- leaky result report ---
# train acc, test acc | 0.4923, 0.4449
# --- leaky result report ---
# train acc, test acc | 0.54118, 0.4848
# --- leaky result report ---
# train acc, test acc | 0.53516, 0.4791
# --- leaky result report ---
# train acc, test acc | 0.53606, 0.4799
# --- leaky result report ---
# train acc, test acc | 0.50904, 0.4575
# --- leaky result report ---
# train acc, test acc | 0.53672, 0.4726
# --- leaky result report ---
# train acc, test acc | 0.5137, 0.4541
# --- leaky result report ---
# train acc, test acc | 0.54292, 0.4873
# --- leaky result report ---
# train acc, test acc | 0.51726, 0.4548
# --- leaky result report ---
# train acc, test acc | 0.54114, 0.4776
# --- leaky result report ---
# train acc, test acc | 0.54218, 0.4755
# --- leaky result report ---
# train acc, test acc | 0.539, 0.4774
# --- leaky result report ---
# train acc, test acc | 0.53202, 0.4722
# --- leaky result report ---
# train acc, test acc | 0.51964, 0.4648
# --- leaky result report ---
# train acc, test acc | 0.52792, 0.4647
# --- leaky result report ---
# train acc, test acc | 0.54418, 0.4839
# --- leaky result report ---
# train acc, test acc | 0.55192, 0.4823
# --- leaky result report ---
# train acc, test acc | 0.52758, 0.4596
# --- leaky result report ---
# train acc, test acc | 0.54016, 0.4691
# --- leaky result report ---
# train acc, test acc | 0.54188, 0.4744
# --- leaky result report ---
# train acc, test acc | 0.5549, 0.4883
# --- leaky result report ---
# train acc, test acc | 0.53774, 0.472
# --- leaky result report ---
# train acc, test acc | 0.55208, 0.48
# --- leaky result report ---
# train acc, test acc | 0.54284, 0.4708
# --- leaky result report ---
# train acc, test acc | 0.54838, 0.4709
# --- leaky result report ---
# train acc, test acc | 0.5603, 0.484
# --- leaky result report ---
# train acc, test acc | 0.53224, 0.4633
# --- leaky result report ---
# train acc, test acc | 0.54892, 0.4793
# --- leaky result report ---
# train acc, test acc | 0.5661, 0.4941
# --- leaky result report ---
# train acc, test acc | 0.5567, 0.4797
# --- leaky result report ---
# train acc, test acc | 0.5516, 0.4694
# --- leaky result report ---
# train acc, test acc | 0.53316, 0.4634
# --- leaky result report ---
# train acc, test acc | 0.55982, 0.4846
# --- leaky result report ---
# train acc, test acc | 0.56768, 0.4827
# --- leaky result report ---
# train acc, test acc | 0.54758, 0.4688
# --- leaky result report ---
# train acc, test acc | 0.55466, 0.4683
# --- leaky result report ---
# train acc, test acc | 0.56806, 0.4878
# --- leaky result report ---
# train acc, test acc | 0.51454, 0.4516
# --- leaky result report ---
# train acc, test acc | 0.57454, 0.4916
# --- leaky result report ---
# train acc, test acc | 0.55748, 0.4755
# --- leaky result report ---
# train acc, test acc | 0.54478, 0.4665
# --- leaky result report ---
# train acc, test acc | 0.57612, 0.4917
# --- leaky result report ---
# train acc, test acc | 0.57518, 0.4872
# --- leaky result report ---
# train acc, test acc | 0.57138, 0.4811
# --- leaky result report ---
# train acc, test acc | 0.56534, 0.4814
# --- leaky result report ---
# train acc, test acc | 0.54998, 0.4638
# --- leaky result report ---
# train acc, test acc | 0.57358, 0.4838
# --- leaky result report ---
# train acc, test acc | 0.57676, 0.4819
# --- leaky result report ---
# train acc, test acc | 0.55816, 0.4682
# --- leaky result report ---
# train acc, test acc | 0.5695, 0.4882
# --- leaky result report ---
# train acc, test acc | 0.5464, 0.4576
# --- leaky result report ---
# train acc, test acc | 0.56978, 0.4847
# --- leaky result report ---
# train acc, test acc | 0.57002, 0.4765
# --- leaky result report ---
# train acc, test acc | 0.58396, 0.485
# --- leaky result report ---
# train acc, test acc | 0.57192, 0.4837
# --- leaky result report ---
# train acc, test acc | 0.57112, 0.4883
# --- leaky result report ---
# train acc, test acc | 0.58144, 0.4843
# --- leaky result report ---
# train acc, test acc | 0.54084, 0.4546
# --- leaky result report ---
# train acc, test acc | 0.5875, 0.4887
# --- leaky result report ---
# train acc, test acc | 0.56472, 0.4682
# --- leaky result report ---
# train acc, test acc | 0.57478, 0.482
# --- leaky result report ---
# train acc, test acc | 0.58008, 0.4775
# --- leaky result report ---
# train acc, test acc | 0.5853, 0.4807
# running time is 418.6038100719452
# ==========
