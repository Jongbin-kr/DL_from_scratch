# %%
import sys
import os

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

sys.path.append('../../official_github')
from dataset.mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

# %%
# 데이터 읽기
(x_train, t_train), (x_test, t_test) = \
    load_mnist(normalize=False, one_hot_label=False)

# %%
print(x_train.shape)
print(np.max(x_train))
print(t_train.shape)
# Out:
# (60000, 784)
# 255
# (60000,)

# %%
network_dict = {
                'step': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='step', weight_init_std=0.01),
                'sigmoid': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='sigmoid', weight_init_std=0.01),
                'tanh': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='tanh', weight_init_std=0.01),
                'relu': MultiLayerNetExtend(input_size=784, hidden_size_list=[50], output_size=10, activation='relu', weight_init_std=0.01),
                'leaky': MultiLayerNetExtend(input_size=784, hidden_size_list=[100], output_size=10, activation='leaky', weight_init_std=0.01),
                }

# %%
network_dict['relu'].params.keys()
# Out:
# dict_keys(['W1', 'b1', 'W2', 'b2'])

# %%
# 하이퍼 파라메터
iters_num = 10_000  # 반복횟수
train_size = x_train.shape[0]
batch_size = 100  # 미니배치 크기
learning_rate = 0.1
iter_per_epoch = max(train_size / batch_size, 1)

# %%
output_dict = {}
for key, network in network_dict.items():

    # optimizer = SGD(lr=learning_rate)
    
    output_dict[f'{key} train acc'] = []
    output_dict[f'{key} test acc'] = []
    
    print(f'=== {key} network training start ===')
    for i in range(iters_num):
        # print(i)
        # 미니배치 획득
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        # 오차역전파법으로 기울기 계산
        grad = network.gradient(x_batch, t_batch)

        # 매개변수 갱신
        for param in ('W1', 'b1', 'W2', 'b2'):
            network.params[param] -= learning_rate * grad[param]

        # 학습 경과 기록
        loss = network.loss(x_batch, t_batch)
        # print('loss:', loss)

        # 1에폭 당 정확도 계산
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            output_dict[f'{key} train acc'].append(train_acc)
            output_dict[f'{key} test acc'].append(test_acc)
            print(f'--- {key} result report ---')
            print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
        
    print('='*10)
    print('\n\n')
# Out:
# === step network training start ===
# --- step result report ---
# train acc, test acc | 0.16358333333333333, 0.1593
# --- step result report ---
# train acc, test acc | 0.7793, 0.7881
# --- step result report ---
# train acc, test acc | 0.7924833333333333, 0.7997
# --- step result report ---
# train acc, test acc | 0.7977, 0.8044
# --- step result report ---
# train acc, test acc | 0.7994333333333333, 0.8061
# --- step result report ---
# train acc, test acc | 0.8028, 0.8085
# --- step result report ---
# train acc, test acc | 0.80295, 0.8079
# --- step result report ---
# train acc, test acc | 0.8022333333333334, 0.8087
# --- step result report ---
# train acc, test acc | 0.8039, 0.8072
# --- step result report ---
# train acc, test acc | 0.8052666666666667, 0.8093
# --- step result report ---
# train acc, test acc | 0.8055833333333333, 0.811
# --- step result report ---
# train acc, test acc | 0.80535, 0.8113
# --- step result report ---
# train acc, test acc | 0.8053166666666667, 0.8113
# --- step result report ---
# train acc, test acc | 0.8061166666666667, 0.8121
# --- step result report ---
# train acc, test acc | 0.8057166666666666, 0.8098
# --- step result report ---
# train acc, test acc | 0.80715, 0.8107
# --- step result report ---
# train acc, test acc | 0.8061833333333334, 0.8114
# ==========
#
#
#
# === sigmoid network training start ===
# --- sigmoid result report ---
# train acc, test acc | 0.20728333333333335, 0.2085
# /home/jongbin/OneDrive_korea/2_My-Programming/0_DL_from_scratch/experiment/MLP_activation_function/../../official_github/common/functions.py:14: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# --- sigmoid result report ---
# train acc, test acc | 0.8707166666666667, 0.8733
# --- sigmoid result report ---
# train acc, test acc | 0.8863, 0.8927
# --- sigmoid result report ---
# train acc, test acc | 0.8908333333333334, 0.8984
# --- sigmoid result report ---
# train acc, test acc | 0.88625, 0.8884
# --- sigmoid result report ---
# train acc, test acc | 0.8864, 0.8913
# --- sigmoid result report ---
# train acc, test acc | 0.89485, 0.8984
# --- sigmoid result report ---
# train acc, test acc | 0.8936166666666666, 0.9012
# --- sigmoid result report ---
# train acc, test acc | 0.8929333333333334, 0.8956
# --- sigmoid result report ---
# train acc, test acc | 0.8956666666666667, 0.895
# --- sigmoid result report ---
# train acc, test acc | 0.8849833333333333, 0.8856
# --- sigmoid result report ---
# train acc, test acc | 0.8892, 0.8899
# --- sigmoid result report ---
# train acc, test acc | 0.8996, 0.905
# --- sigmoid result report ---
# train acc, test acc | 0.9063333333333333, 0.9077
# --- sigmoid result report ---
# train acc, test acc | 0.9085833333333333, 0.9078
# --- sigmoid result report ---
# train acc, test acc | 0.9015833333333333, 0.9015
# --- sigmoid result report ---
# train acc, test acc | 0.8972666666666667, 0.8981
# ==========
#
#
#
# === tanh network training start ===
# --- tanh result report ---
# train acc, test acc | 0.2805, 0.2855
# --- tanh result report ---
# train acc, test acc | 0.7080166666666666, 0.7119
# --- tanh result report ---
# train acc, test acc | 0.7302, 0.7341
# --- tanh result report ---
# train acc, test acc | 0.6981, 0.6941
# --- tanh result report ---
# train acc, test acc | 0.7507, 0.7528
# --- tanh result report ---
# train acc, test acc | 0.7366166666666667, 0.7418
# --- tanh result report ---
# train acc, test acc | 0.7472333333333333, 0.7502
# --- tanh result report ---
# train acc, test acc | 0.74505, 0.7473
# --- tanh result report ---
# train acc, test acc | 0.7939166666666667, 0.7974
# --- tanh result report ---
# train acc, test acc | 0.79615, 0.8007
# --- tanh result report ---
# train acc, test acc | 0.78035, 0.785
# --- tanh result report ---
# train acc, test acc | 0.7923333333333333, 0.7915
# --- tanh result report ---
# train acc, test acc | 0.7987, 0.7997
# --- tanh result report ---
# train acc, test acc | 0.7979166666666667, 0.8015
# --- tanh result report ---
# train acc, test acc | 0.8053333333333333, 0.8148
# --- tanh result report ---
# train acc, test acc | 0.8038166666666666, 0.8056
# --- tanh result report ---
# train acc, test acc | 0.8227833333333333, 0.8192
# ==========
#
#
#
# === relu network training start ===
# /home/jongbin/OneDrive_korea/2_My-Programming/0_DL_from_scratch/experiment/MLP_activation_function/../../official_github/common/functions.py:56: RuntimeWarning: divide by zero encountered in log
#   return -np.sum(np.log(y[np.arange(batch_size), t])) / batch_size
# --- relu result report ---
# train acc, test acc | 0.10486666666666666, 0.1034
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# --- relu result report ---
# train acc, test acc | 0.11236666666666667, 0.1135
# ==========
#
#
#
# === leaky network training start ===
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# /home/jongbin/OneDrive_korea/2_My-Programming/0_DL_from_scratch/experiment/MLP_activation_function/../../official_github/common/functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# --- leaky result report ---
# train acc, test acc | 0.09871666666666666, 0.098
# ==========

# %%
for k, v in output_dict.items():
    print(k)
    
    x = range(len(v))
    
    if k.startswith('step'):
        color_code = 'y'
    elif k.startswith('sigmoid'):
        color_code = 'r'
    elif k.startswith('tanh'):
        color_code = 'm'
    elif k.startswith('relu'):
        color_code = 'b'
    elif k.startswith('leaky'):
        color_code = 'c'

    if 'train' in k:
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    
    plt.plot(x, v, linestyle=linestyle, color=color_code, label = k)
        

plt.ylim([0.0, 1.0])   
plt.legend()
plt.grid()
# Out:
# step train acc
# step test acc
# sigmoid train acc
# sigmoid test acc
# tanh train acc
# tanh test acc
# relu train acc
# relu test acc
# leaky train acc
# leaky test acc
