# %%
import numpy as np

# %% [markdown]
# ## 6.1.최적화 기법

# %%
class SGD:
    def __init__(self, lr=0.01) -> None:
        self.lr = lr
    
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
    
    def update(self, params, grads):
        if self.v is None:
            self.v = {}           
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
        
        for key in params.keys():
            self.v[key] = self.momentum * self.v[key] - self.lr * grads[key]
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
        
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / np.sqrt(self.h[key] + 1e-7)

# %% [markdown]
# ## 6.2.가중치의 초깃값
# + 초깃값이 왜 중요한가?
#   + 가중치가 너무 크다면, 특정 특징에 과대하게 영향을 받아 오버피팅 현상이 일어날 수 있다.
#   + 따라서 이를 방지하고자, 가중치의 매개변수 값이 작아지도록 설정하거나(weight decay), 아예 처음부터 초깃값을 작게 설정하기도 한다.
#   + 적절한 초깃값 설정을 통해서 활성화함수를 거친 값이 균일하게 분포하도록 하는 것이 중요하다.
#     + 활성화함수로 ReLU를 사용할 때는 He초깃값을, 시그모이드 함수를 사용할 경우에는 Xavier초깃값을 사용하는 것이 좋다.
